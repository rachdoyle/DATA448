# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: optuna in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: cmaes>=0.9.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (0.9.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.22.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.4.46)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (4.64.1)
# Requirement already satisfied: alembic>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.10.2)
# Requirement already satisfied: PyYAML in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (5.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (21.3)
# Requirement already satisfied: colorlog in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: Mako in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.simplefilter(action= 'ignore', category=FutureWarning)

import boto3
import pandas as pd
import numpy as np

from tqdm import tqdm
from scipy.stats import boxcox
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.feature_selection import RFE, RFECV
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier 
from sklearn.metrics import classification_report, make_scorer, confusion_matrix
import optuna

from cost_function import cost_function, cost_function_cutoff 
##defining the bucket
s3 = boto3.resource('s3')
bucket_name = 'rachaeld-data445'
bucket = s3.Bucket(bucket_name)

#defining the csv file
file_key = 'train.csv'
file_key2 = 'test.csv'

##train
bucket_object = bucket.Object(file_key)
file_object = bucket_object.get()
file_content_stream = file_object.get('Body')

##test
bucket_object2 = bucket.Object(file_key2)
file_object2 = bucket_object2.get()
file_content_stream2 = file_object2.get('Body')

train = pd.read_csv(file_content_stream)
test = pd.read_csv(file_content_stream2)

# %%
test.rename(columns={'lineItemVoids':'lineItemsVoids'}, inplace=True)

# %%
train.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemsVoids  \
# 0           5                    1054       54.70               7
# 1           3                     108       27.36               5
# 2           3                    1516       62.16               3
# 3           6                    1791       92.31               8
# 4           5                     430       81.53               3
#
#    scansWithoutRegistration  quanitityModification  scannedLineItemsPerSecond  \
# 0                         0                      3                   0.027514
# 1                         2                      4                   0.129630
# 2                        10                      5                   0.008575
# 3                         4                      4                   0.016192
# 4                         7                      2                   0.062791
#
#    valuePerSecond  lineItemVoidsPerPosition  fraud
# 0        0.051898                  0.241379      0
# 1        0.253333                  0.357143      0
# 2        0.041003                  0.230769      0
# 3        0.051541                  0.275862      0
# 4        0.189605                  0.111111      0

# %%
test.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemsVoids  \
# 0         4.0                   467.0       88.48               4
# 1         3.0                  1004.0       58.99               7
# 2         1.0                   162.0       14.00               4
# 3         5.0                   532.0       84.79               9
# 4         5.0                   890.0       42.16               4
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         8                      4                   0.014989
# 1                         6                      1                   0.026892
# 2                         5                      4                   0.006173
# 3                         3                      4                   0.026316
# 4                         0                      0                   0.021348
#
#    valuePerSecond  lineItemVoidsPerPosition  newtrustLevel  ...  \
# 0        0.189465                  0.571429       2.354358  ...
# 1        0.058755                  0.259259       1.660831  ...
# 2        0.086420                  4.000000       0.000000  ...
# 3        0.159380                  0.642857       2.998293  ...
# 4        0.047371                  0.210526       2.998293  ...
#
#    valuePerSecond_cubed  Naturallog_grandTotal  log10_totalScanTimeInSeconds  \
# 0              0.006801               4.482777                      2.669317
# 1              0.000203               4.077368                      3.001734
# 2              0.000645               2.639057                      2.209515
# 3              0.004049               4.440178                      2.725912
# 4              0.000106               3.741472                      2.949390
#
#    0_1_scansWithoutRegistration  interaction_1  interaction_2  interaction_3  \
# 0                             1       9.417431     157.069293     266.857149
# 1                             1       4.982493      61.758306     111.555557
# 2                             1       0.000000       0.000000     161.999987
# 3                             0      14.991465     113.935136     190.000003
# 4                             0      14.991465     140.446353     234.210522
#
#    tree_interaction1  tree_interaction_2  tree_interaction_3
# 0                  0                   0                   1
# 1                  0                   0                   1
# 2                  1                   0                   0
# 3                  0                   0                   1
# 4                  0                   0                   1
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Exercise 2

# %%
## engineering variables from homework 4
##boxcox
transformed_trustLevel= boxcox(train['trustLevel'])
train['newtrustLevel'] = transformed_trustLevel[0]
transformed_trustLevel= boxcox(test['trustLevel'])
test['newtrustLevel'] = transformed_trustLevel[0]

##1/x
train['1/scannedLineItemsPerSecond']= 1/(train['scannedLineItemsPerSecond'])
test['1/scannedLineItemsPerSecond']= 1/(test['scannedLineItemsPerSecond'])

##^2
train['lineItemVoidsPerPosition_squared'] = train['lineItemVoidsPerPosition']**2
test['lineItemVoidsPerPosition_squared'] = test['lineItemVoidsPerPosition']**2

##^3
train['valuePerSecond_cubed'] = train['valuePerSecond'] **3
test['valuePerSecond_cubed'] = test['valuePerSecond'] **3

##natural log
train['Naturallog_grandTotal'] = np.log(train['grandTotal'])
test['Naturallog_grandTotal'] = np.log(test['grandTotal'])

##log base 10
train['log10_totalScanTimeInSeconds'] = np.log10(train['totalScanTimeInSeconds'])
test['log10_totalScanTimeInSeconds'] = np.log10(test['totalScanTimeInSeconds'])

## >5
train['0_1_scansWithoutRegistration'] = np.where(train['scansWithoutRegistration'] < 5, 0, 1) 
test['0_1_scansWithoutRegistration'] = np.where(test['scansWithoutRegistration'] < 5, 0, 1)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
##engineering interactions based on feature importance from homework 4
train['interaction_1'] = train['newtrustLevel'] * train['trustLevel']
test['interaction_1'] = test['newtrustLevel'] * test['trustLevel']

train['interaction_2'] = train['newtrustLevel'] * train['1/scannedLineItemsPerSecond']
test['interaction_2'] = test['newtrustLevel'] * test['1/scannedLineItemsPerSecond']

train['interaction_3'] = train['trustLevel'] * train['1/scannedLineItemsPerSecond']
test['interaction_3'] = test['trustLevel'] * test['1/scannedLineItemsPerSecond']

# %%
## final interactions from homework 4 
##interaction 1 <= .862 for all
train['tree_interaction1'] = np.where(train['interaction_1'] <= 0.862, 1, 0)

## interaction 1 --> interaction 1 --> totalScanTimeInSeconds 
train['tree_interaction_2'] = np.where(((train['interaction_1'] >= .862) & 
                                     (train['interaction_1'] <= 3.204) & 
                                     (train['totalScanTimeInSeconds'] <= 1298)), 1, 0)

## interaction 1 (.862) --> 1/scannedLineItemsPerSecond (86.763) --> log10_totalScanTimeInSeconds (3.022)
train['tree_interaction_3'] = np.where(((train['interaction_1'] >= .862) & 
                                     (train['1/scannedLineItemsPerSecond'] <= 86.763) & 
                                     (train['log10_totalScanTimeInSeconds'] <= 3.022)), 1, 0)

## same things for test
test['tree_interaction1'] = np.where(test['interaction_1'] <= 0.862, 1, 0)

test['tree_interaction_2'] = np.where(((test['interaction_1'] >= .862) & 
                                     (test['interaction_1'] <= 3.204) & 
                                     (test['totalScanTimeInSeconds'] <= 1298)), 1, 0)

test['tree_interaction_3'] = np.where(((test['interaction_1'] >= .862) & 
                                     (test['1/scannedLineItemsPerSecond'] <= 86.763) & 
                                     (test['log10_totalScanTimeInSeconds'] <= 3.022)), 1, 0)

# %%
# TOP 7 
# log10_totalScanTimeInSeconds
# interaction_3
# totalScanTimeInSeconds
# tree_interaction_2
# interaction_1
# lineItemVoidsPerPosition_squared
# lineItemsVoids

X_train_5 = train[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds', 'tree_interaction_2', 'interaction_1']]

X_train_6 = train[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds',
                   'tree_interaction_2', 'interaction_1', 'lineItemVoidsPerPosition_squared']]

X_train_7 = train[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds',
                   'tree_interaction_2', 'interaction_1', 'lineItemVoidsPerPosition_squared', 'lineItemsVoids']]

Y_train = train[['fraud']]

# %% [markdown]
# (85 points) Using the train data-frame (including the top 7 features from homework assignment
# 5), do the following:
#
# (i) Consider a model to predict fraud. Then, do the following:
#
#     • With the top 5 important features and using the GridSearchCV function with cv = 3,
#     run a hyper-parameter tuning procedure on the model. Please see page 4 of
#     DATA-MINING-CUP-2019-task.pdf file to understand how the model should be evaluated.
#
#     • With the top 6 important features and using the GridSearchCV function with cv = 3,
#     run a hyper-parameter tuning procedure on the model. Please see page 4 of
#     DATA-MINING-CUP-2019-task.pdf file to understand how the model should be evaluated.
#
#     • With the top 7 important features and using the GridSearchCV function with cv = 3,
#     run a hyper-parameter tuning procedure on the model. Please see page 4 of
#     DATA-MINING-CUP-2019-task.pdf file to understand how the model should be evaluated.
#
# From above three scenarios, identify the best model; that is, the model model (input features
# and hyper-parameters) that has the best performance.

# %%
#defining scorer
my_scorer = make_scorer(cost_function, greater_is_better = True, needs_proba = True)

# %%
## Gradient Boosting with GridSearchCV
GB_param_grid = {'n_estimators': [100, 300],
                  'min_samples_split': [10, 15],
                  'min_samples_leaf': [5, 7],
                  'max_depth': [3, 5, 7],
                  'learning_rate': [0.001, 0.01, 0.1]}

##top 5 variables
GB_grid_search_1 = GridSearchCV(estimator = GradientBoostingClassifier(), param_grid = GB_param_grid, cv = 3, 
                                scoring = my_scorer).fit(X_train_5, Y_train)
print('The best params with Gradient Boosting and GridSearchCV for the top 5 variables is:', GB_grid_search_1.best_params_ )

##top 6 variables
GB_grid_search_2 = GridSearchCV(estimator = GradientBoostingClassifier(), param_grid = GB_param_grid, cv = 3, 
                                scoring = my_scorer).fit(X_train_6, Y_train)
print('The best params with Gradient Boosting and GridSearchCV for the top 6 variables is:', GB_grid_search_2.best_params_ )

##top 7 variables
GB_grid_search_3 = GridSearchCV(estimator = GradientBoostingClassifier(), param_grid = GB_param_grid, cv = 3, 
                                scoring = my_scorer).fit(X_train_7, Y_train)
print('The best params with Gradient Boosting and GridSearchCV for the top 7 variables is:', GB_grid_search_3.best_params_ )
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The best params with Gradient Boosting and GridSearchCV for the top 7 variables is: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 15, 'n_estimators': 100}

# %%
GB_best_score_1 = GB_grid_search_1.best_score_
print('The best params with Gradient Boosting and GridSearchCV for the top 5 variables is:', GB_grid_search_1.best_params_ )
print('The best score for the top 5 variables is:', GB_best_score_1)

GB_best_score_2 = GB_grid_search_2.best_score_
print('The best params with Gradient Boosting and GridSearchCV for the top 6 variables is:', GB_grid_search_2.best_params_ )
print('The best score for the top 6 variables is:', GB_best_score_2)

GB_best_score_3 = GB_grid_search_3.best_score_
print('The best params with Gradient Boosting and GridSearchCV for the top 7 variables is:', GB_grid_search_3.best_params_ )
print('The best score for the top 7 variables is:', GB_best_score_3)
# Out:
# The best params with Gradient Boosting and GridSearchCV for the top 5 variables is: {'learning_rate': 0.01, 'max_depth': 5, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 300}
# The best score for the top 5 variables is: -15.0
# The best params with Gradient Boosting and GridSearchCV for the top 6 variables is: {'learning_rate': 0.01, 'max_depth': 5, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 300}
# The best score for the top 6 variables is: -11.666666666666666
# The best params with Gradient Boosting and GridSearchCV for the top 7 variables is: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 15, 'n_estimators': 100}
# The best score for the top 7 variables is: 11.666666666666666

# %% [markdown]
# (ii) Consider a model different from part (i) to predict fraud. Then, do the following:
#
#     • With the top 5 important features and using the RandomizedSearchCV function with cv
#     = 3 and n iter = 30, run a hyper-parameter tuning procedure on the model. Please
#     see page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model
#     should be evaluated.
#
#     • With the top 6 important features and using the RandomizedSearchCV function with cv
#     = 3 and n iter = 30, run a hyper-parameter tuning procedure on the model. Please
#     see page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model
#     should be evaluated.
#
#     • With the top 7 important features and using the RandomizedSearchCV function with cv
#     = 3 and n iter = 30, run a hyper-parameter tuning procedure on the model. Please
#     see page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model
#     should be evaluated.

# %%
### ADABOOST
ADA_param_grid = {'n_estimators': [100, 300],
                  'estimator__min_samples_split': [10, 15],
                  'estimator__min_samples_leaf': [5, 7],
                  'estimator__max_depth': [3, 5, 7],
                  'learning_rate': [0.001, 0.01, 0.1]}

##top 5 variables
ADA_random_search_1 = RandomizedSearchCV(estimator = AdaBoostClassifier(estimator = DecisionTreeClassifier()), 
                                             param_distributions = ADA_param_grid, cv = 3, scoring = my_scorer,
                                             n_jobs = -1, n_iter = 30).fit(X_train_5, Y_train)
print('The best params with ADAboost and RandomizedSearchCV for the top 5 variables is:', ADA_random_search_1.best_params_ )

##top 6 variables
ADA_random_search_2 = RandomizedSearchCV(estimator = AdaBoostClassifier(estimator = DecisionTreeClassifier()), 
                                             param_distributions = ADA_param_grid, cv = 3, scoring = my_scorer,
                                             n_jobs = -1, n_iter = 30).fit(X_train_6, Y_train)
print('The best params with ADAboost and RandomizedSearchCV for the top 6 variables is:', ADA_random_search_2.best_params_ )

##top 7 variables
ADA_random_search_3 = RandomizedSearchCV(estimator = AdaBoostClassifier(estimator = DecisionTreeClassifier()), 
                                             param_distributions = ADA_param_grid, cv = 3, scoring = my_scorer,
                                             n_jobs = -1, n_iter = 30).fit(X_train_7, Y_train)
print('The best params with ADAboost and RandomizedSearchCV for the top 7 variables is:', ADA_random_search_3.best_params_ )
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The best params with ADAboost and RandomizedSearchCV for the top 5 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 15, 'estimator__min_samples_leaf': 7, 'estimator__max_depth': 3}
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The best params with ADAboost and RandomizedSearchCV for the top 7 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 5, 'estimator__max_depth': 3}

# %%
ADA_best_score_1 = ADA_random_search_1.best_score_
print('The best params with ADAboost and RandomizedSearchCV for the top 5 variables is:', ADA_random_search_1.best_params_ )
print('The best score is:', ADA_best_score_1)

ADA_best_score_2 = ADA_random_search_2.best_score_
print('The best params with ADAboost and RandomizedSearchCV for the top 6 variables is:', ADA_random_search_2.best_params_ )
print('The best score is:', ADA_best_score_2)

ADA_best_score_3 = ADA_random_search_3.best_score_
print('The best params with ADAboost and RandomizedSearchCV for the top 7 variables is:', ADA_random_search_3.best_params_ )
print('The best score is:', ADA_best_score_3)
# Out:
# The best params with ADAboost and RandomizedSearchCV for the top 5 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 15, 'estimator__min_samples_leaf': 7, 'estimator__max_depth': 3}
# The best score is: -8.333333333333334
# The best params with ADAboost and RandomizedSearchCV for the top 6 variables is: {'n_estimators': 100, 'learning_rate': 0.01, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 7, 'estimator__max_depth': 5}
# The best score is: -13.333333333333334
# The best params with ADAboost and RandomizedSearchCV for the top 7 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 5, 'estimator__max_depth': 3}
# The best score is: 3.3333333333333335

# %% [markdown]
# (iii) Consider a model different from parts (i) & (ii) to predict fraud. Then, do the following:
#
#     • With the top 5 important features and using the Optuna framework using 3 folds and
#     N TRIALS = 30, run a hyper-parameter tuning procedure on the model. Please see
#     page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model should
#     be evaluated.
#
#     • With the top 6 important features and using the Optuna framework using 3 folds and
#     N TRIALS = 30, run a hyper-parameter tuning procedure on the model. Please see
#     page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model should
#     be evaluated.
#
#     • With the top 7 important features and using the Optuna framework using 3 folds and
#     N TRIALS = 30, run a hyper-parameter tuning procedure on the model. Please see
#     page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model should
#     be evaluated.

# %%
## Random Forest and Optuna 

##Top 5 variables
class Objective:
    def __init__(self, seed):
        self.seed = seed
        
    def __call__(self, trial):
        params = dict(n_estimators = trial.suggest_int('n_estimators', 100, 2000),
                        min_samples_split = trial.suggest_int('min_samples_split', 5, 30),
                        min_samples_leaf = trial.suggest_int('min_samples_leaf', 5, 30),
                        max_depth = trial.suggest_int('max_depth', 2, 10)
                        )
        scores = list()
        
        skf = StratifiedKFold(n_splits = 3, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X_train_5, Y_train):
            X_train_1, X_valid_1 = X_train_5.iloc[train_idx], X_train_5.iloc[valid_idx]
            Y_train_1, Y_valid_1 = Y_train.iloc[train_idx], Y_train.iloc[valid_idx]
            
            RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
            pred_valid = RF_md.predict_proba(X_valid_1)[:, 1]
            score = cost_function(Y_valid_1, pred_valid)
            scores.append(score)
            
        return np.mean(scores)

# %%
SEED = 42
N_TRIALS = 30

study = optuna.create_study(direction = 'maximize')
study.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-03-31 14:57:34,553] A new study created in memory with name: no-name-c4246e68-ba12-4da1-aed5-1eb47fbf7328
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:35,707] Trial 0 finished with value: -70.0 and parameters: {'n_estimators': 171, 'min_samples_split': 5, 'min_samples_leaf': 27, 'max_depth': 2}. Best is trial 0 with value: -70.0.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:39,131] Trial 1 finished with value: -16.666666666666668 and parameters: {'n_estimators': 608, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_depth': 6}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:43,250] Trial 2 finished with value: -73.33333333333333 and parameters: {'n_estimators': 827, 'min_samples_split': 19, 'min_samples_leaf': 22, 'max_depth': 2}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:45,695] Trial 3 finished with value: -30.0 and parameters: {'n_estimators': 450, 'min_samples_split': 23, 'min_samples_leaf': 22, 'max_depth': 6}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:49,817] Trial 4 finished with value: -33.333333333333336 and parameters: {'n_estimators': 698, 'min_samples_split': 30, 'min_samples_leaf': 19, 'max_depth': 6}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:58,419] Trial 5 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1531, 'min_samples_split': 19, 'min_samples_leaf': 17, 'max_depth': 10}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:58:01,080] Trial 6 finished with value: -61.666666666666664 and parameters: {'n_estimators': 470, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_depth': 3}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:58:07,377] Trial 7 finished with value: -76.66666666666667 and parameters: {'n_estimators': 1194, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_depth': 2}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:58:15,047] Trial 8 finished with value: -26.666666666666668 and parameters: {'n_estimators': 1375, 'min_samples_split': 7, 'min_samples_leaf': 23, 'max_depth': 9}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:58:24,240] Trial 9 finished with value: -63.333333333333336 and parameters: {'n_estimators': 1657, 'min_samples_split': 14, 'min_samples_leaf': 18, 'max_depth': 3}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:58:35,092] Trial 10 finished with value: -30.0 and parameters: {'n_estimators': 1904, 'min_samples_split': 26, 'min_samples_leaf': 6, 'max_depth': 7}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:58:41,535] Trial 11 finished with value: -35.0 and parameters: {'n_estimators': 1176, 'min_samples_split': 11, 'min_samples_leaf': 12, 'max_depth': 9}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:58:49,561] Trial 12 finished with value: -31.666666666666668 and parameters: {'n_estimators': 1440, 'min_samples_split': 12, 'min_samples_leaf': 12, 'max_depth': 8}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:58:54,491] Trial 13 finished with value: -38.333333333333336 and parameters: {'n_estimators': 900, 'min_samples_split': 16, 'min_samples_leaf': 30, 'max_depth': 5}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:01,840] Trial 14 finished with value: -31.666666666666668 and parameters: {'n_estimators': 1293, 'min_samples_split': 23, 'min_samples_leaf': 13, 'max_depth': 8}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:02,596] Trial 15 finished with value: -35.0 and parameters: {'n_estimators': 113, 'min_samples_split': 9, 'min_samples_leaf': 25, 'max_depth': 5}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:06,132] Trial 16 finished with value: -21.666666666666668 and parameters: {'n_estimators': 604, 'min_samples_split': 22, 'min_samples_leaf': 9, 'max_depth': 10}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:09,538] Trial 17 finished with value: -35.0 and parameters: {'n_estimators': 582, 'min_samples_split': 22, 'min_samples_leaf': 8, 'max_depth': 5}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:11,536] Trial 18 finished with value: -28.333333333333332 and parameters: {'n_estimators': 333, 'min_samples_split': 27, 'min_samples_leaf': 9, 'max_depth': 10}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:16,325] Trial 19 finished with value: -36.666666666666664 and parameters: {'n_estimators': 837, 'min_samples_split': 20, 'min_samples_leaf': 15, 'max_depth': 7}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:22,275] Trial 20 finished with value: -33.333333333333336 and parameters: {'n_estimators': 1053, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_depth': 4}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:26,225] Trial 21 finished with value: -23.333333333333332 and parameters: {'n_estimators': 694, 'min_samples_split': 17, 'min_samples_leaf': 22, 'max_depth': 9}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:30,066] Trial 22 finished with value: -28.333333333333332 and parameters: {'n_estimators': 655, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_depth': 9}. Best is trial 1 with value: -16.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:32,293] Trial 23 finished with value: -16.666666666666668 and parameters: {'n_estimators': 372, 'min_samples_split': 21, 'min_samples_leaf': 10, 'max_depth': 10}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:34,227] Trial 24 finished with value: -31.666666666666668 and parameters: {'n_estimators': 321, 'min_samples_split': 25, 'min_samples_leaf': 10, 'max_depth': 10}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:35,887] Trial 25 finished with value: -33.333333333333336 and parameters: {'n_estimators': 274, 'min_samples_split': 21, 'min_samples_leaf': 14, 'max_depth': 7}. Best is trial 1 with value: -16.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:38,598] Trial 26 finished with value: -33.333333333333336 and parameters: {'n_estimators': 460, 'min_samples_split': 24, 'min_samples_leaf': 11, 'max_depth': 8}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:44,019] Trial 27 finished with value: -25.0 and parameters: {'n_estimators': 941, 'min_samples_split': 28, 'min_samples_leaf': 7, 'max_depth': 10}. Best is trial 1 with value: -16.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:47,251] Trial 28 finished with value: -30.0 and parameters: {'n_estimators': 557, 'min_samples_split': 19, 'min_samples_leaf': 15, 'max_depth': 8}. Best is trial 1 with value: -16.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:49,005] Trial 29 finished with value: -25.0 and parameters: {'n_estimators': 287, 'min_samples_split': 21, 'min_samples_leaf': 8, 'max_depth': 7}. Best is trial 1 with value: -16.666666666666668.

# %%
##Top 6 variables
class Objective:
    def __init__(self, seed):
        self.seed = seed
        
        
        
    def __call__(self, trial):
        params = dict(n_estimators = trial.suggest_int('n_estimators', 100, 2000),
                        min_samples_split = trial.suggest_int('min_samples_split', 6, 30),
                        min_samples_leaf = trial.suggest_int('min_samples_leaf', 6, 30),
                        max_depth = trial.suggest_int('max_depth', 2, 10)
                        )
        scores = list()
        
        skf = StratifiedKFold(n_splits = 3, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X_train_6, Y_train):
            X_train_1, X_valid_1 = X_train_6.iloc[train_idx], X_train_6.iloc[valid_idx]
            Y_train_1, Y_valid_1 = Y_train.iloc[train_idx], Y_train.iloc[valid_idx]
            
            RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
            pred_valid = RF_md.predict_proba(X_valid_1)[:, 1]
            score = cost_function(Y_valid_1, pred_valid)
            scores.append(score)
            
        return np.mean(scores)

# %%
SEED = 42
N_TRIALS = 30

study2 = optuna.create_study(direction = 'maximize')
study2.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-03-31 14:53:31,235] A new study created in memory with name: no-name-653b5c42-dac9-49e8-940f-978a300b6d90
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:53:35,182] Trial 0 finished with value: -45.0 and parameters: {'n_estimators': 660, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_depth': 8}. Best is trial 0 with value: -45.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:53:36,994] Trial 1 finished with value: -43.333333333333336 and parameters: {'n_estimators': 325, 'min_samples_split': 25, 'min_samples_leaf': 23, 'max_depth': 8}. Best is trial 1 with value: -43.333333333333336.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:53:40,685] Trial 2 finished with value: -66.66666666666667 and parameters: {'n_estimators': 742, 'min_samples_split': 11, 'min_samples_leaf': 22, 'max_depth': 2}. Best is trial 1 with value: -43.333333333333336.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:53:51,361] Trial 3 finished with value: -36.666666666666664 and parameters: {'n_estimators': 1922, 'min_samples_split': 7, 'min_samples_leaf': 22, 'max_depth': 7}. Best is trial 3 with value: -36.666666666666664.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:53:59,271] Trial 4 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1391, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_depth': 7}. Best is trial 3 with value: -36.666666666666664.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:54:07,064] Trial 5 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1372, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_depth': 7}. Best is trial 3 with value: -36.666666666666664.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:54:10,957] Trial 6 finished with value: -45.0 and parameters: {'n_estimators': 678, 'min_samples_split': 12, 'min_samples_leaf': 16, 'max_depth': 9}. Best is trial 3 with value: -36.666666666666664.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:54:16,944] Trial 7 finished with value: -65.0 and parameters: {'n_estimators': 1145, 'min_samples_split': 26, 'min_samples_leaf': 20, 'max_depth': 2}. Best is trial 3 with value: -36.666666666666664.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:54:25,962] Trial 8 finished with value: -46.666666666666664 and parameters: {'n_estimators': 1630, 'min_samples_split': 18, 'min_samples_leaf': 25, 'max_depth': 5}. Best is trial 3 with value: -36.666666666666664.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:54:28,716] Trial 9 finished with value: -41.666666666666664 and parameters: {'n_estimators': 483, 'min_samples_split': 24, 'min_samples_leaf': 29, 'max_depth': 6}. Best is trial 3 with value: -36.666666666666664.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:54:39,549] Trial 10 finished with value: -15.0 and parameters: {'n_estimators': 1860, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:54:50,957] Trial 11 finished with value: -18.333333333333332 and parameters: {'n_estimators': 1990, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:55:02,015] Trial 12 finished with value: -18.333333333333332 and parameters: {'n_estimators': 1998, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:55:12,249] Trial 13 finished with value: -15.0 and parameters: {'n_estimators': 1764, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:55:21,726] Trial 14 finished with value: -33.333333333333336 and parameters: {'n_estimators': 1657, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:55:31,069] Trial 15 finished with value: -35.0 and parameters: {'n_estimators': 1649, 'min_samples_split': 10, 'min_samples_leaf': 16, 'max_depth': 4}. Best is trial 10 with value: -15.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:55:37,322] Trial 16 finished with value: -30.0 and parameters: {'n_estimators': 1087, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_depth': 9}. Best is trial 10 with value: -15.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:55:45,469] Trial 17 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1419, 'min_samples_split': 30, 'min_samples_leaf': 6, 'max_depth': 9}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:55:55,797] Trial 18 finished with value: -35.0 and parameters: {'n_estimators': 1836, 'min_samples_split': 14, 'min_samples_leaf': 13, 'max_depth': 4}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:55:56,683] Trial 19 finished with value: -45.0 and parameters: {'n_estimators': 135, 'min_samples_split': 8, 'min_samples_leaf': 16, 'max_depth': 8}. Best is trial 10 with value: -15.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:56:06,723] Trial 20 finished with value: -35.0 and parameters: {'n_estimators': 1764, 'min_samples_split': 9, 'min_samples_leaf': 11, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:56:15,551] Trial 21 finished with value: -15.0 and parameters: {'n_estimators': 1529, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:56:23,953] Trial 22 finished with value: -21.666666666666668 and parameters: {'n_estimators': 1464, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_depth': 9}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:56:31,251] Trial 23 finished with value: -25.0 and parameters: {'n_estimators': 1237, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:56:36,574] Trial 24 finished with value: -18.333333333333332 and parameters: {'n_estimators': 910, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_depth': 9}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:56:45,271] Trial 25 finished with value: -45.0 and parameters: {'n_estimators': 1538, 'min_samples_split': 16, 'min_samples_leaf': 14, 'max_depth': 8}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:56:55,366] Trial 26 finished with value: -35.0 and parameters: {'n_estimators': 1777, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:02,616] Trial 27 finished with value: -21.666666666666668 and parameters: {'n_estimators': 1259, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_depth': 9}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:12,799] Trial 28 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1814, 'min_samples_split': 6, 'min_samples_leaf': 18, 'max_depth': 10}. Best is trial 10 with value: -15.0.
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2693979497.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:57:17,938] Trial 29 finished with value: -35.0 and parameters: {'n_estimators': 910, 'min_samples_split': 16, 'min_samples_leaf': 12, 'max_depth': 8}. Best is trial 10 with value: -15.0.

# %%
##Top 7 variables
class Objective:
    def __init__(self, seed):
        self.seed = seed
        
    def __call__(self, trial):
        params = dict(n_estimators = trial.suggest_int('n_estimators', 100, 2000),
                        min_samples_split = trial.suggest_int('min_samples_split', 7, 30),
                        min_samples_leaf = trial.suggest_int('min_samples_leaf', 7, 30),
                        max_depth = trial.suggest_int('max_depth', 2, 10)
                        )
        scores = list()
        
        skf = StratifiedKFold(n_splits = 3, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X_train_7, Y_train):
            X_train_1, X_valid_1 = X_train_7.iloc[train_idx], X_train_7.iloc[valid_idx]
            Y_train_1, Y_valid_1 = Y_train.iloc[train_idx], Y_train.iloc[valid_idx]
            
            RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
            pred_valid = RF_md.predict_proba(X_valid_1)[:, 1]
            score = cost_function(Y_valid_1, pred_valid)
            scores.append(score)
            
        return np.mean(scores)

# %%
SEED = 42
N_TRIALS = 30

study3 = optuna.create_study(direction = 'maximize')
study3.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-03-31 14:59:49,022] A new study created in memory with name: no-name-5fa847e4-9693-4cd4-98b0-fbb86cb8d1dc
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:53,314] Trial 0 finished with value: -48.333333333333336 and parameters: {'n_estimators': 766, 'min_samples_split': 30, 'min_samples_leaf': 30, 'max_depth': 9}. Best is trial 0 with value: -48.333333333333336.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 14:59:57,702] Trial 1 finished with value: -48.333333333333336 and parameters: {'n_estimators': 776, 'min_samples_split': 20, 'min_samples_leaf': 21, 'max_depth': 6}. Best is trial 0 with value: -48.333333333333336.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:00,407] Trial 2 finished with value: -40.0 and parameters: {'n_estimators': 467, 'min_samples_split': 30, 'min_samples_leaf': 19, 'max_depth': 7}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:09,685] Trial 3 finished with value: -55.0 and parameters: {'n_estimators': 1636, 'min_samples_split': 27, 'min_samples_leaf': 22, 'max_depth': 7}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:20,012] Trial 4 finished with value: -48.333333333333336 and parameters: {'n_estimators': 1821, 'min_samples_split': 23, 'min_samples_leaf': 27, 'max_depth': 10}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:27,286] Trial 5 finished with value: -53.333333333333336 and parameters: {'n_estimators': 1312, 'min_samples_split': 10, 'min_samples_leaf': 28, 'max_depth': 9}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:28,898] Trial 6 finished with value: -53.333333333333336 and parameters: {'n_estimators': 276, 'min_samples_split': 26, 'min_samples_leaf': 12, 'max_depth': 3}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:33,620] Trial 7 finished with value: -56.666666666666664 and parameters: {'n_estimators': 898, 'min_samples_split': 20, 'min_samples_leaf': 21, 'max_depth': 2}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:36,115] Trial 8 finished with value: -68.33333333333333 and parameters: {'n_estimators': 415, 'min_samples_split': 7, 'min_samples_leaf': 24, 'max_depth': 2}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:37,452] Trial 9 finished with value: -48.333333333333336 and parameters: {'n_estimators': 195, 'min_samples_split': 19, 'min_samples_leaf': 28, 'max_depth': 8}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:44,165] Trial 10 finished with value: -41.666666666666664 and parameters: {'n_estimators': 1233, 'min_samples_split': 16, 'min_samples_leaf': 15, 'max_depth': 5}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:51,398] Trial 11 finished with value: -48.333333333333336 and parameters: {'n_estimators': 1286, 'min_samples_split': 14, 'min_samples_leaf': 15, 'max_depth': 5}. Best is trial 2 with value: -40.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:00:58,178] Trial 12 finished with value: -41.666666666666664 and parameters: {'n_estimators': 1205, 'min_samples_split': 15, 'min_samples_leaf': 15, 'max_depth': 5}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:01,469] Trial 13 finished with value: -41.666666666666664 and parameters: {'n_estimators': 573, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_depth': 4}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:10,684] Trial 14 finished with value: -48.333333333333336 and parameters: {'n_estimators': 1614, 'min_samples_split': 17, 'min_samples_leaf': 15, 'max_depth': 7}. Best is trial 2 with value: -40.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:16,530] Trial 15 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1026, 'min_samples_split': 23, 'min_samples_leaf': 10, 'max_depth': 6}. Best is trial 15 with value: -38.333333333333336.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:19,885] Trial 16 finished with value: -40.0 and parameters: {'n_estimators': 576, 'min_samples_split': 30, 'min_samples_leaf': 7, 'max_depth': 7}. Best is trial 15 with value: -38.333333333333336.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:26,283] Trial 17 finished with value: -31.666666666666668 and parameters: {'n_estimators': 1058, 'min_samples_split': 25, 'min_samples_leaf': 10, 'max_depth': 6}. Best is trial 17 with value: -31.666666666666668.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:32,436] Trial 18 finished with value: -43.333333333333336 and parameters: {'n_estimators': 1078, 'min_samples_split': 23, 'min_samples_leaf': 10, 'max_depth': 6}. Best is trial 17 with value: -31.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:40,714] Trial 19 finished with value: -45.0 and parameters: {'n_estimators': 1489, 'min_samples_split': 23, 'min_samples_leaf': 11, 'max_depth': 4}. Best is trial 17 with value: -31.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:46,264] Trial 20 finished with value: -41.666666666666664 and parameters: {'n_estimators': 958, 'min_samples_split': 26, 'min_samples_leaf': 10, 'max_depth': 4}. Best is trial 17 with value: -31.666666666666668.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:49,918] Trial 21 finished with value: -46.666666666666664 and parameters: {'n_estimators': 639, 'min_samples_split': 28, 'min_samples_leaf': 18, 'max_depth': 6}. Best is trial 17 with value: -31.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:55,951] Trial 22 finished with value: -43.333333333333336 and parameters: {'n_estimators': 1063, 'min_samples_split': 25, 'min_samples_leaf': 18, 'max_depth': 8}. Best is trial 17 with value: -31.666666666666668.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:01:58,144] Trial 23 finished with value: -40.0 and parameters: {'n_estimators': 389, 'min_samples_split': 22, 'min_samples_leaf': 13, 'max_depth': 8}. Best is trial 17 with value: -31.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:02:09,896] Trial 24 finished with value: -45.0 and parameters: {'n_estimators': 1978, 'min_samples_split': 28, 'min_samples_leaf': 9, 'max_depth': 6}. Best is trial 17 with value: -31.666666666666668.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:02:14,730] Trial 25 finished with value: -50.0 and parameters: {'n_estimators': 867, 'min_samples_split': 25, 'min_samples_leaf': 19, 'max_depth': 7}. Best is trial 17 with value: -31.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:02:22,643] Trial 26 finished with value: -45.0 and parameters: {'n_estimators': 1440, 'min_samples_split': 21, 'min_samples_leaf': 17, 'max_depth': 5}. Best is trial 17 with value: -31.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:02:23,474] Trial 27 finished with value: -35.0 and parameters: {'n_estimators': 125, 'min_samples_split': 29, 'min_samples_leaf': 13, 'max_depth': 6}. Best is trial 17 with value: -31.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:02:24,466] Trial 28 finished with value: -40.0 and parameters: {'n_estimators': 153, 'min_samples_split': 24, 'min_samples_leaf': 13, 'max_depth': 6}. Best is trial 17 with value: -31.666666666666668.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 15:02:28,560] Trial 29 finished with value: -31.666666666666668 and parameters: {'n_estimators': 707, 'min_samples_split': 29, 'min_samples_leaf': 8, 'max_depth': 9}. Best is trial 17 with value: -31.666666666666668.

# %%
print('The best parameters for the top 5 variables is:', study.best_trial.params)
print('The best parameters for the top 6 variables is:', study2.best_trial.params)
print('The best parameters for the top 7 variables is:', study3.best_trial.params)

'''
5: Best is trial 1 with value: -16.666666666666668.
6:  Best is trial 10 with value: -15.0.
7:  Best is trial 17 with value: -31.666666666666668.
'''
# Out:
# The best parameters for the top 5 variables is: {'n_estimators': 608, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_depth': 6}
# The best parameters for the top 6 variables is: {'n_estimators': 1860, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_depth': 10}
# The best parameters for the top 7 variables is: {'n_estimators': 1058, 'min_samples_split': 25, 'min_samples_leaf': 10, 'max_depth': 6}
# '\n5: Best is trial 1 with value: -16.666666666666668.\n6:  Best is trial 10 with value: -15.0.\n7:  Best is trial 17 with value: -31.666666666666668.\n'

# %% [markdown]
# ## Exercise 3
#
# (70 points) Using the train data-frame and the models from exercise 2, split the train data-frame
# into two data-frames: training (80%) and validation (20%) taking into account the proportions
# of 0s and 1s. Then, do the following:

# %%
X = train[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds',
                   'tree_interaction_2', 'interaction_1', 'lineItemVoidsPerPosition_squared', 'lineItemsVoids']]
Y = train['fraud']

X_training, X_valid, Y_training, Y_valid = train_test_split(X, Y, test_size = .2, stratify = Y)

# %%
test1 = test[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds',
                   'tree_interaction_2', 'interaction_1', 'lineItemVoidsPerPosition_squared', 'lineItemsVoids']]

X_training6 = X_training.drop(columns = ['lineItemsVoids'])
X_valid6 = X_valid.drop(columns = ['lineItemsVoids'])
test6 = test1.drop(columns = ['lineItemsVoids'])

# %% [markdown]
# (i) Consider the best model from exercise 2(i). Build that model on the training data-frame.
# After that, predict the likelihood of fraud on the validation and test data-frames.

# %%
'''
The best params with Gradient Boosting and GridSearchCV for the top 7 variables is: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 15, 'n_estimators': 100}
The best score for the top 7 variables is: 11.666666666666666
'''

##building the model
GB_md = GradientBoostingClassifier(n_estimators = 100, max_depth = 3, learning_rate = 0.1,
                                   min_samples_leaf = 7, min_samples_split = 15).fit(X_training, Y_training)
##predicting on validation and test
GB_val_pred = GB_md.predict_proba(X_valid)[:, 1]
GB_test_pred = GB_md.predict_proba(test1)[:, 1]

##computing cost
print('Cost function score of GB model:',cost_function(Y_valid, GB_val_pred))
print('Cutoff value for GB model:', cost_function_cutoff(Y_valid, GB_val_pred))
# Out:
# Cost function score of GB model: 35.0
# Cutoff value for GB model: 0.6

# %% [markdown]
# (ii) Consider the best model from exercise 2(ii). Build that model on the training data-frame.
# After that, predict the likelihood of fraud on the validation and test data-frames

# %%
'''
The best params with ADAboost and RandomizedSearchCV for the top 7 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 5, 'estimator__max_depth': 3}
The best score is: 3.3333333333333335
'''
##building the model
ADA_md = AdaBoostClassifier(estimator = DecisionTreeClassifier(max_depth = 3, min_samples_leaf = 5, min_samples_split = 10),
                        learning_rate = 0.1, n_estimators = 100).fit(X_training, Y_training)
##predicting on validation and test
ADA_val_pred = ADA_md.predict_proba(X_valid)[:, 1]
ADA_test_pred = ADA_md.predict_proba(test1)[:, 1]

##computing cost
print('Cost function score of ADA model:',cost_function(Y_valid, ADA_val_pred))
print('Cutoff value for ADA model:', cost_function_cutoff(Y_valid, ADA_val_pred))
# Out:
# Cost function score of ADA model: 20.0
# Cutoff value for ADA model: 0.63

# %% [markdown]
# (iii) Consider the best model from exercise 2(iii). Build that model on the training data-frame.
# After that, predict the likelihood of fraud on the validation and test data-frames.

# %%
'''
The best parameters for the top 6 variables is: {'n_estimators': 1860, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_depth': 10}
'''

##building the model
RF_md = RandomForestClassifier(max_depth = 10, min_samples_leaf = 6, min_samples_split = 9, n_estimators = 1860).fit(X_training6, Y_training)

##predicting on validation and test
RF_val_pred = RF_md.predict_proba(X_valid6)[:, 1]
RF_test_pred = RF_md.predict_proba(test6)[:, 1]

##computing cost
print('Cost function score of RF model:',cost_function(Y_valid, RF_val_pred))
print('Cutoff value for RF model:',cost_function_cutoff(Y_valid, RF_val_pred))
# Out:
# Cost function score of RF model: -40.0
# Cutoff value for RF model: 0.53

# %% [markdown]
# Using the prediction on the validation data-frame as inputs from parts (i)-(ii)-(iii) and the
# actual fraud values from the validation data-frame as the target variable, build a meta-learner
# to predict fraud. Make sure to tune the hyper-parameters of the meta-learner keeping in mind how
# the results are going to be evaluated. For more info, see page 4 of DATA-MINING-CUP-2019-task.pdf
# file. Finally, use the best meta-learner to predict the likelihood of fraud in the test data-frame.
# Submit the likelihoods in a csv file. Also submit the associated cut-off value

# %%
'''
GB:
    Cost function score of GB model: 35.0
    Cutoff value for GB model: 0.6
ADA:
    Cost function score of ADA model: 20.0
    Cutoff value for ADA model: 0.63
RF:
    Cost function score of RF model: -40.0
    Cutoff value for RF model: 0.53

'''

# %%
from sklearn.tree import DecisionTreeClassifier

X_ensemble = pd.concat([pd.DataFrame(GB_val_pred),pd.DataFrame(ADA_val_pred), pd.DataFrame(RF_val_pred)], axis = 1)
X_testensemble = pd.concat([pd.DataFrame(GB_test_pred),pd.DataFrame(ADA_test_pred), pd.DataFrame(RF_test_pred)], axis = 1)

X = X_ensemble
Y = Y_valid

class Objective:
    def __init__(self, seed):
        self.seed = seed

    def __call__(self, trial):
        
        ## Parameters being evaluated
        params = dict(n_estimators = trial.suggest_int('n_estimators', 100, 2000),
        min_samples_split = trial.suggest_int('min_samples_split', 5, 30),
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 5, 30),
        max_depth = trial.suggest_int('max_depth', 2, 10)
        )
        scores = []
        
        ##Cross Validation 
        skf = StratifiedKFold(n_splits = 3, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X, Y):
            X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
            Y_train , Y_valid = Y.iloc[train_idx] , Y.iloc[valid_idx]
            RF_md = RandomForestClassifier(**params).fit(X_train, Y_train)
            preds_valid = RF_md.predict_proba(X_valid)[:, 1]
            score = cost_function(Y_valid, preds_valid)
            scores.append(score)
        return np.mean(scores)

# %%
#defining seed and number of trials
SEED = 42
N_TRIALS = 30

#execute an optimization
study = optuna.create_study(direction = 'maximize')
study.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-03-31 15:46:00,530] A new study created in memory with name: no-name-42828a3a-6072-4ae7-a633-47f2405be63f
# [I 2023-03-31 15:46:05,159] Trial 0 finished with value: 11.666666666666666 and parameters: {'n_estimators': 1012, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:12,254] Trial 1 finished with value: -35.0 and parameters: {'n_estimators': 1702, 'min_samples_split': 18, 'min_samples_leaf': 23, 'max_depth': 7}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:16,270] Trial 2 finished with value: -35.0 and parameters: {'n_estimators': 955, 'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 8}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:21,798] Trial 3 finished with value: -28.333333333333332 and parameters: {'n_estimators': 1320, 'min_samples_split': 20, 'min_samples_leaf': 18, 'max_depth': 8}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:27,431] Trial 4 finished with value: -11.666666666666666 and parameters: {'n_estimators': 1347, 'min_samples_split': 29, 'min_samples_leaf': 15, 'max_depth': 10}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:31,059] Trial 5 finished with value: -35.0 and parameters: {'n_estimators': 859, 'min_samples_split': 26, 'min_samples_leaf': 29, 'max_depth': 9}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:37,573] Trial 6 finished with value: -35.0 and parameters: {'n_estimators': 1511, 'min_samples_split': 14, 'min_samples_leaf': 25, 'max_depth': 7}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:45,202] Trial 7 finished with value: -35.0 and parameters: {'n_estimators': 1769, 'min_samples_split': 14, 'min_samples_leaf': 30, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:53,091] Trial 8 finished with value: -3.3333333333333335 and parameters: {'n_estimators': 1854, 'min_samples_split': 25, 'min_samples_leaf': 15, 'max_depth': 5}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:55,384] Trial 9 finished with value: 11.666666666666666 and parameters: {'n_estimators': 526, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:56,448] Trial 10 finished with value: 11.666666666666666 and parameters: {'n_estimators': 227, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_depth': 4}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:46:58,432] Trial 11 finished with value: 11.666666666666666 and parameters: {'n_estimators': 455, 'min_samples_split': 21, 'min_samples_leaf': 5, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:01,053] Trial 12 finished with value: 8.333333333333334 and parameters: {'n_estimators': 645, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_depth': 4}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:03,755] Trial 13 finished with value: 11.666666666666666 and parameters: {'n_estimators': 619, 'min_samples_split': 22, 'min_samples_leaf': 9, 'max_depth': 3}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:04,639] Trial 14 finished with value: -1.6666666666666667 and parameters: {'n_estimators': 184, 'min_samples_split': 17, 'min_samples_leaf': 11, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# [I 2023-03-31 15:47:09,358] Trial 15 finished with value: 8.333333333333334 and parameters: {'n_estimators': 1096, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_depth': 4}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:12,777] Trial 16 finished with value: -3.3333333333333335 and parameters: {'n_estimators': 789, 'min_samples_split': 24, 'min_samples_leaf': 13, 'max_depth': 5}. Best is trial 0 with value: 11.666666666666666.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# [I 2023-03-31 15:47:17,398] Trial 17 finished with value: 11.666666666666666 and parameters: {'n_estimators': 1073, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_depth': 3}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:19,318] Trial 18 finished with value: -28.333333333333332 and parameters: {'n_estimators': 434, 'min_samples_split': 30, 'min_samples_leaf': 19, 'max_depth': 3}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:24,647] Trial 19 finished with value: 11.666666666666666 and parameters: {'n_estimators': 1238, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_depth': 6}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:26,459] Trial 20 finished with value: -1.6666666666666667 and parameters: {'n_estimators': 406, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_depth': 5}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:27,253] Trial 21 finished with value: 11.666666666666666 and parameters: {'n_estimators': 160, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_depth': 4}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:27,823] Trial 22 finished with value: 8.333333333333334 and parameters: {'n_estimators': 107, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_depth': 3}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:29,448] Trial 23 finished with value: 11.666666666666666 and parameters: {'n_estimators': 368, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:32,266] Trial 24 finished with value: 11.666666666666666 and parameters: {'n_estimators': 647, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_depth': 4}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:33,636] Trial 25 finished with value: 11.666666666666666 and parameters: {'n_estimators': 297, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_depth': 3}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:36,008] Trial 26 finished with value: -3.3333333333333335 and parameters: {'n_estimators': 540, 'min_samples_split': 22, 'min_samples_leaf': 14, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:39,422] Trial 27 finished with value: 11.666666666666666 and parameters: {'n_estimators': 785, 'min_samples_split': 27, 'min_samples_leaf': 8, 'max_depth': 3}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:40,738] Trial 28 finished with value: -28.333333333333332 and parameters: {'n_estimators': 292, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_depth': 6}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 15:47:47,967] Trial 29 finished with value: -20.0 and parameters: {'n_estimators': 1568, 'min_samples_split': 18, 'min_samples_leaf': 16, 'max_depth': 4}. Best is trial 0 with value: 11.666666666666666.

# %%
'''
Best is trial 0 with value: 11.666666666666666.
'''
print('Best combination for ensemble model:', study.best_trial.params)
# Out:
# Best combination for ensemble model: {'n_estimators': 1012, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_depth': 2}

# %%
#building ensemble model with optimal hyperparameters (fitted on predictions from validation)
RF_ens_md =RandomForestClassifier(**study.best_trial.params).fit(X_ensemble, Y_valid)

#predicting on validation & test
RF_ens_val_pred = RF_ens_md.predict_proba(X_ensemble)[:, 1]
RF_ens_test_pred = RF_ens_md.predict_proba(X_testensemble)[:, 1]

#identifying the optimal cutoff
opt_cutoff = cost_function_cutoff(Y_valid, RF_ens_val_pred)
print('The optimal cutoff for the ensemble  is:', opt_cutoff)
# Out:
# The optimal cutoff for the ensemble  is: 0.81

# %%
##exporting test predictions as csv
likelihoods = pd.DataFrame({'Likelihoods': RF_ens_test_pred})
likelihoods.to_csv('likelihoods.csv', index = False)
