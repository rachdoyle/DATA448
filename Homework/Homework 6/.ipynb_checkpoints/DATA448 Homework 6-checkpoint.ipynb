# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: optuna in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: cmaes>=0.9.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (0.9.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.22.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.4.46)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (4.64.1)
# Requirement already satisfied: alembic>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.10.2)
# Requirement already satisfied: PyYAML in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (5.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (21.3)
# Requirement already satisfied: colorlog in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: Mako in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.simplefilter(action= 'ignore', category=FutureWarning)

import boto3
import pandas as pd
import numpy as np

from tqdm import tqdm
from scipy.stats import boxcox
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.feature_selection import RFE, RFECV
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier 
from sklearn.metrics import classification_report, make_scorer, confusion_matrix
import optuna

from cost_function import cost_function, cost_function_cutoff 
##defining the bucket
s3 = boto3.resource('s3')
bucket_name = 'rachaeld-data445'
bucket = s3.Bucket(bucket_name)

#defining the csv file
file_key = 'train.csv'
file_key2 = 'test.csv'

##train
bucket_object = bucket.Object(file_key)
file_object = bucket_object.get()
file_content_stream = file_object.get('Body')

##test
bucket_object2 = bucket.Object(file_key2)
file_object2 = bucket_object2.get()
file_content_stream2 = file_object2.get('Body')

train = pd.read_csv(file_content_stream)
test = pd.read_csv(file_content_stream2)

# %%
test.rename(columns={'lineItemVoids':'lineItemsVoids'}, inplace=True)

# %%
train.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemsVoids  \
# 0           5                    1054       54.70               7
# 1           3                     108       27.36               5
# 2           3                    1516       62.16               3
# 3           6                    1791       92.31               8
# 4           5                     430       81.53               3
#
#    scansWithoutRegistration  quanitityModification  scannedLineItemsPerSecond  \
# 0                         0                      3                   0.027514
# 1                         2                      4                   0.129630
# 2                        10                      5                   0.008575
# 3                         4                      4                   0.016192
# 4                         7                      2                   0.062791
#
#    valuePerSecond  lineItemVoidsPerPosition  fraud
# 0        0.051898                  0.241379      0
# 1        0.253333                  0.357143      0
# 2        0.041003                  0.230769      0
# 3        0.051541                  0.275862      0
# 4        0.189605                  0.111111      0

# %%
test.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemsVoids  \
# 0         4.0                   467.0       88.48               4
# 1         3.0                  1004.0       58.99               7
# 2         1.0                   162.0       14.00               4
# 3         5.0                   532.0       84.79               9
# 4         5.0                   890.0       42.16               4
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         8                      4                   0.014989
# 1                         6                      1                   0.026892
# 2                         5                      4                   0.006173
# 3                         3                      4                   0.026316
# 4                         0                      0                   0.021348
#
#    valuePerSecond  lineItemVoidsPerPosition  newtrustLevel  ...  \
# 0        0.189465                  0.571429       2.354358  ...
# 1        0.058755                  0.259259       1.660831  ...
# 2        0.086420                  4.000000       0.000000  ...
# 3        0.159380                  0.642857       2.998293  ...
# 4        0.047371                  0.210526       2.998293  ...
#
#    valuePerSecond_cubed  Naturallog_grandTotal  log10_totalScanTimeInSeconds  \
# 0              0.006801               4.482777                      2.669317
# 1              0.000203               4.077368                      3.001734
# 2              0.000645               2.639057                      2.209515
# 3              0.004049               4.440178                      2.725912
# 4              0.000106               3.741472                      2.949390
#
#    0_1_scansWithoutRegistration  interaction_1  interaction_2  interaction_3  \
# 0                             1       9.417431     157.069293     266.857149
# 1                             1       4.982493      61.758306     111.555557
# 2                             1       0.000000       0.000000     161.999987
# 3                             0      14.991465     113.935136     190.000003
# 4                             0      14.991465     140.446353     234.210522
#
#    tree_interaction1  tree_interaction_2  tree_interaction_3
# 0                  0                   0                   1
# 1                  0                   0                   1
# 2                  1                   0                   0
# 3                  0                   0                   1
# 4                  0                   0                   1
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Exercise 2

# %%
## engineering variables from homework 4
##boxcox
transformed_trustLevel= boxcox(train['trustLevel'])
train['newtrustLevel'] = transformed_trustLevel[0]
transformed_trustLevel= boxcox(test['trustLevel'])
test['newtrustLevel'] = transformed_trustLevel[0]

##1/x
train['1/scannedLineItemsPerSecond']= 1/(train['scannedLineItemsPerSecond'])
test['1/scannedLineItemsPerSecond']= 1/(test['scannedLineItemsPerSecond'])

##^2
train['lineItemVoidsPerPosition_squared'] = train['lineItemVoidsPerPosition']**2
test['lineItemVoidsPerPosition_squared'] = test['lineItemVoidsPerPosition']**2

##^3
train['valuePerSecond_cubed'] = train['valuePerSecond'] **3
test['valuePerSecond_cubed'] = test['valuePerSecond'] **3

##natural log
train['Naturallog_grandTotal'] = np.log(train['grandTotal'])
test['Naturallog_grandTotal'] = np.log(test['grandTotal'])

##log base 10
train['log10_totalScanTimeInSeconds'] = np.log10(train['totalScanTimeInSeconds'])
test['log10_totalScanTimeInSeconds'] = np.log10(test['totalScanTimeInSeconds'])

## >5
train['0_1_scansWithoutRegistration'] = np.where(train['scansWithoutRegistration'] < 5, 0, 1) 
test['0_1_scansWithoutRegistration'] = np.where(test['scansWithoutRegistration'] < 5, 0, 1)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
##engineering interactions based on feature importance from homework 4
train['interaction_1'] = train['newtrustLevel'] * train['trustLevel']
test['interaction_1'] = test['newtrustLevel'] * test['trustLevel']

train['interaction_2'] = train['newtrustLevel'] * train['1/scannedLineItemsPerSecond']
test['interaction_2'] = test['newtrustLevel'] * test['1/scannedLineItemsPerSecond']

train['interaction_3'] = train['trustLevel'] * train['1/scannedLineItemsPerSecond']
test['interaction_3'] = test['trustLevel'] * test['1/scannedLineItemsPerSecond']

# %%
## final interactions from homework 4 
##interaction 1 <= .862 for all
train['tree_interaction1'] = np.where(train['interaction_1'] <= 0.862, 1, 0)

## interaction 1 --> interaction 1 --> totalScanTimeInSeconds 
train['tree_interaction_2'] = np.where(((train['interaction_1'] >= .862) & 
                                     (train['interaction_1'] <= 3.204) & 
                                     (train['totalScanTimeInSeconds'] <= 1298)), 1, 0)

## interaction 1 (.862) --> 1/scannedLineItemsPerSecond (86.763) --> log10_totalScanTimeInSeconds (3.022)
train['tree_interaction_3'] = np.where(((train['interaction_1'] >= .862) & 
                                     (train['1/scannedLineItemsPerSecond'] <= 86.763) & 
                                     (train['log10_totalScanTimeInSeconds'] <= 3.022)), 1, 0)

## same things for test
test['tree_interaction1'] = np.where(test['interaction_1'] <= 0.862, 1, 0)

test['tree_interaction_2'] = np.where(((test['interaction_1'] >= .862) & 
                                     (test['interaction_1'] <= 3.204) & 
                                     (test['totalScanTimeInSeconds'] <= 1298)), 1, 0)

test['tree_interaction_3'] = np.where(((test['interaction_1'] >= .862) & 
                                     (test['1/scannedLineItemsPerSecond'] <= 86.763) & 
                                     (test['log10_totalScanTimeInSeconds'] <= 3.022)), 1, 0)

# %%
# TOP 7 
# log10_totalScanTimeInSeconds
# interaction_3
# totalScanTimeInSeconds
# tree_interaction_2
# interaction_1
# lineItemVoidsPerPosition_squared
# lineItemsVoids

X_train_5 = train[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds', 'tree_interaction_2', 'interaction_1']]

X_train_6 = train[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds',
                   'tree_interaction_2', 'interaction_1', 'lineItemVoidsPerPosition_squared']]

X_train_7 = train[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds',
                   'tree_interaction_2', 'interaction_1', 'lineItemVoidsPerPosition_squared', 'lineItemsVoids']]

Y_train = train[['fraud']]

# %% [markdown]
# (85 points) Using the train data-frame (including the top 7 features from homework assignment
# 5), do the following:
#
# (i) Consider a model to predict fraud. Then, do the following:
#
#     • With the top 5 important features and using the GridSearchCV function with cv = 3,
#     run a hyper-parameter tuning procedure on the model. Please see page 4 of
#     DATA-MINING-CUP-2019-task.pdf file to understand how the model should be evaluated.
#
#     • With the top 6 important features and using the GridSearchCV function with cv = 3,
#     run a hyper-parameter tuning procedure on the model. Please see page 4 of
#     DATA-MINING-CUP-2019-task.pdf file to understand how the model should be evaluated.
#
#     • With the top 7 important features and using the GridSearchCV function with cv = 3,
#     run a hyper-parameter tuning procedure on the model. Please see page 4 of
#     DATA-MINING-CUP-2019-task.pdf file to understand how the model should be evaluated.
#
# From above three scenarios, identify the best model; that is, the model model (input features
# and hyper-parameters) that has the best performance.

# %%
#defining scorer
my_scorer = make_scorer(cost_function, greater_is_better = True, needs_proba = True)

# %%
## Gradient Boosting with GridSearchCV
GB_param_grid = {'n_estimators': [100, 300],
                  'min_samples_split': [10, 15],
                  'min_samples_leaf': [5, 7],
                  'max_depth': [3, 5, 7],
                  'learning_rate': [0.001, 0.01, 0.1]}

##top 5 variables
GB_grid_search_1 = GridSearchCV(estimator = GradientBoostingClassifier(), param_grid = GB_param_grid, cv = 3, 
                                scoring = my_scorer).fit(X_train_5, Y_train)
print('The best params with Gradient Boosting and GridSearchCV for the top 5 variables is:', GB_grid_search_1.best_params_ )

##top 6 variables
GB_grid_search_2 = GridSearchCV(estimator = GradientBoostingClassifier(), param_grid = GB_param_grid, cv = 3, 
                                scoring = my_scorer).fit(X_train_6, Y_train)
print('The best params with Gradient Boosting and GridSearchCV for the top 6 variables is:', GB_grid_search_2.best_params_ )

##top 7 variables
GB_grid_search_3 = GridSearchCV(estimator = GradientBoostingClassifier(), param_grid = GB_param_grid, cv = 3, 
                                scoring = my_scorer).fit(X_train_7, Y_train)
print('The best params with Gradient Boosting and GridSearchCV for the top 7 variables is:', GB_grid_search_3.best_params_ )
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The best params with Gradient Boosting and GridSearchCV for the top 7 variables is: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 15, 'n_estimators': 100}

# %%
GB_best_score_1 = GB_grid_search_1.best_score_
print('The best params with Gradient Boosting and GridSearchCV for the top 5 variables is:', GB_grid_search_1.best_params_ )
print('The best score for the top 5 variables is:', GB_best_score_1)

GB_best_score_2 = GB_grid_search_2.best_score_
print('The best params with Gradient Boosting and GridSearchCV for the top 6 variables is:', GB_grid_search_2.best_params_ )
print('The best score for the top 6 variables is:', GB_best_score_2)

GB_best_score_3 = GB_grid_search_3.best_score_
print('The best params with Gradient Boosting and GridSearchCV for the top 7 variables is:', GB_grid_search_3.best_params_ )
print('The best score for the top 7 variables is:', GB_best_score_3)
# Out:
# The best params with Gradient Boosting and GridSearchCV for the top 5 variables is: {'learning_rate': 0.01, 'max_depth': 5, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 300}
# The best score for the top 5 variables is: -15.0
# The best params with Gradient Boosting and GridSearchCV for the top 6 variables is: {'learning_rate': 0.01, 'max_depth': 5, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 300}
# The best score for the top 6 variables is: -11.666666666666666
# The best params with Gradient Boosting and GridSearchCV for the top 7 variables is: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 15, 'n_estimators': 100}
# The best score for the top 7 variables is: 11.666666666666666

# %% [markdown]
# (ii) Consider a model different from part (i) to predict fraud. Then, do the following:
#
#     • With the top 5 important features and using the RandomizedSearchCV function with cv
#     = 3 and n iter = 30, run a hyper-parameter tuning procedure on the model. Please
#     see page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model
#     should be evaluated.
#
#     • With the top 6 important features and using the RandomizedSearchCV function with cv
#     = 3 and n iter = 30, run a hyper-parameter tuning procedure on the model. Please
#     see page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model
#     should be evaluated.
#
#     • With the top 7 important features and using the RandomizedSearchCV function with cv
#     = 3 and n iter = 30, run a hyper-parameter tuning procedure on the model. Please
#     see page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model
#     should be evaluated.

# %%
### ADABOOST
ADA_param_grid = {'n_estimators': [100, 300],
                  'estimator__min_samples_split': [10, 15],
                  'estimator__min_samples_leaf': [5, 7],
                  'estimator__max_depth': [3, 5, 7],
                  'learning_rate': [0.001, 0.01, 0.1]}

##top 5 variables
ADA_random_search_1 = RandomizedSearchCV(estimator = AdaBoostClassifier(estimator = DecisionTreeClassifier()), 
                                             param_distributions = ADA_param_grid, cv = 3, scoring = my_scorer,
                                             n_jobs = -1, n_iter = 30).fit(X_train_5, Y_train)
print('The best params with ADAboost and RandomizedSearchCV for the top 5 variables is:', ADA_random_search_1.best_params_ )

##top 6 variables
ADA_random_search_2 = RandomizedSearchCV(estimator = AdaBoostClassifier(estimator = DecisionTreeClassifier()), 
                                             param_distributions = ADA_param_grid, cv = 3, scoring = my_scorer,
                                             n_jobs = -1, n_iter = 30).fit(X_train_6, Y_train)
print('The best params with ADAboost and RandomizedSearchCV for the top 6 variables is:', ADA_random_search_2.best_params_ )

##top 7 variables
ADA_random_search_3 = RandomizedSearchCV(estimator = AdaBoostClassifier(estimator = DecisionTreeClassifier()), 
                                             param_distributions = ADA_param_grid, cv = 3, scoring = my_scorer,
                                             n_jobs = -1, n_iter = 30).fit(X_train_7, Y_train)
print('The best params with ADAboost and RandomizedSearchCV for the top 7 variables is:', ADA_random_search_3.best_params_ )
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The best params with ADAboost and RandomizedSearchCV for the top 5 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 15, 'estimator__min_samples_leaf': 7, 'estimator__max_depth': 3}
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The best params with ADAboost and RandomizedSearchCV for the top 7 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 5, 'estimator__max_depth': 3}

# %%
ADA_best_score_1 = ADA_random_search_1.best_score_
print('The best params with ADAboost and RandomizedSearchCV for the top 5 variables is:', ADA_random_search_1.best_params_ )
print('The best score is:', ADA_best_score_1)

ADA_best_score_2 = ADA_random_search_2.best_score_
print('The best params with ADAboost and RandomizedSearchCV for the top 6 variables is:', ADA_random_search_2.best_params_ )
print('The best score is:', ADA_best_score_2)

ADA_best_score_3 = ADA_random_search_3.best_score_
print('The best params with ADAboost and RandomizedSearchCV for the top 7 variables is:', ADA_random_search_3.best_params_ )
print('The best score is:', ADA_best_score_3)
# Out:
# The best params with ADAboost and RandomizedSearchCV for the top 5 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 15, 'estimator__min_samples_leaf': 7, 'estimator__max_depth': 3}
# The best score is: -8.333333333333334
# The best params with ADAboost and RandomizedSearchCV for the top 6 variables is: {'n_estimators': 100, 'learning_rate': 0.01, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 7, 'estimator__max_depth': 5}
# The best score is: -13.333333333333334
# The best params with ADAboost and RandomizedSearchCV for the top 7 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 5, 'estimator__max_depth': 3}
# The best score is: 3.3333333333333335

# %% [markdown]
# (iii) Consider a model different from parts (i) & (ii) to predict fraud. Then, do the following:
#
#     • With the top 5 important features and using the Optuna framework using 3 folds and
#     N TRIALS = 30, run a hyper-parameter tuning procedure on the model. Please see
#     page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model should
#     be evaluated.
#
#     • With the top 6 important features and using the Optuna framework using 3 folds and
#     N TRIALS = 30, run a hyper-parameter tuning procedure on the model. Please see
#     page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model should
#     be evaluated.
#
#     • With the top 7 important features and using the Optuna framework using 3 folds and
#     N TRIALS = 30, run a hyper-parameter tuning procedure on the model. Please see
#     page 4 of DATA-MINING-CUP-2019-task.pdf file to understand how the model should
#     be evaluated.

# %%
## Random Forest and Optuna 

##Top 5 variables
class Objective:
    def __init__(self, seed):
        self.seed = seed
        
    def __call__(self, trial):
        params = dict(n_estimators = trial.suggest_int('n_estimators', 100, 2000),
                        min_samples_split = trial.suggest_int('min_samples_split', 5, 30),
                        min_samples_leaf = trial.suggest_int('min_samples_leaf', 5, 30),
                        max_depth = trial.suggest_int('max_depth', 2, 10)
                        )
        scores = list()
        
        skf = StratifiedKFold(n_splits = 3, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X_train_5, Y_train):
            X_train_1, X_valid_1 = X_train_5.iloc[train_idx], X_train_5.iloc[valid_idx]
            Y_train_1, Y_valid_1 = Y_train.iloc[train_idx], Y_train.iloc[valid_idx]
            
            RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
            pred_valid = RF_md.predict_proba(X_valid_1)[:, 1]
            score = cost_function(Y_valid_1, pred_valid)
            scores.append(score)
            
        return np.mean(scores)

# %%
SEED = 42
N_TRIALS = 30

study = optuna.create_study(direction = 'maximize')
study.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-03-31 00:25:33,697] A new study created in memory with name: no-name-94f6d889-8fe4-4c59-8bcd-342bcca89f99
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:25:40,121] Trial 0 finished with value: -21.666666666666668 and parameters: {'n_estimators': 1075, 'min_samples_split': 23, 'min_samples_leaf': 6, 'max_depth': 5}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:25:43,575] Trial 1 finished with value: -71.66666666666667 and parameters: {'n_estimators': 691, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_depth': 2}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:25:45,298] Trial 2 finished with value: -40.0 and parameters: {'n_estimators': 315, 'min_samples_split': 12, 'min_samples_leaf': 23, 'max_depth': 4}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:25:47,489] Trial 3 finished with value: -68.33333333333333 and parameters: {'n_estimators': 432, 'min_samples_split': 20, 'min_samples_leaf': 28, 'max_depth': 2}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:25:49,269] Trial 4 finished with value: -38.333333333333336 and parameters: {'n_estimators': 325, 'min_samples_split': 26, 'min_samples_leaf': 26, 'max_depth': 4}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:25:52,347] Trial 5 finished with value: -38.333333333333336 and parameters: {'n_estimators': 548, 'min_samples_split': 22, 'min_samples_leaf': 17, 'max_depth': 4}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:25:54,722] Trial 6 finished with value: -65.0 and parameters: {'n_estimators': 422, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_depth': 3}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:01,691] Trial 7 finished with value: -25.0 and parameters: {'n_estimators': 1259, 'min_samples_split': 15, 'min_samples_leaf': 23, 'max_depth': 9}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:06,821] Trial 8 finished with value: -23.333333333333332 and parameters: {'n_estimators': 844, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_depth': 10}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:11,027] Trial 9 finished with value: -66.66666666666667 and parameters: {'n_estimators': 856, 'min_samples_split': 23, 'min_samples_leaf': 24, 'max_depth': 2}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:21,206] Trial 10 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1893, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_depth': 7}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:27,640] Trial 11 finished with value: -28.333333333333332 and parameters: {'n_estimators': 1189, 'min_samples_split': 28, 'min_samples_leaf': 10, 'max_depth': 10}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:35,713] Trial 12 finished with value: -35.0 and parameters: {'n_estimators': 1506, 'min_samples_split': 30, 'min_samples_leaf': 14, 'max_depth': 7}. Best is trial 0 with value: -21.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:40,874] Trial 13 finished with value: -30.0 and parameters: {'n_estimators': 944, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_depth': 6}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:49,835] Trial 14 finished with value: -21.666666666666668 and parameters: {'n_estimators': 1584, 'min_samples_split': 25, 'min_samples_leaf': 5, 'max_depth': 6}. Best is trial 0 with value: -21.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:26:59,811] Trial 15 finished with value: -33.333333333333336 and parameters: {'n_estimators': 1785, 'min_samples_split': 27, 'min_samples_leaf': 17, 'max_depth': 6}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:27:08,523] Trial 16 finished with value: -33.333333333333336 and parameters: {'n_estimators': 1538, 'min_samples_split': 24, 'min_samples_leaf': 12, 'max_depth': 5}. Best is trial 0 with value: -21.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:27:16,789] Trial 17 finished with value: -21.666666666666668 and parameters: {'n_estimators': 1468, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 8}. Best is trial 0 with value: -21.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:27:17,600] Trial 18 finished with value: -31.666666666666668 and parameters: {'n_estimators': 123, 'min_samples_split': 30, 'min_samples_leaf': 5, 'max_depth': 5}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:27:24,199] Trial 19 finished with value: -30.0 and parameters: {'n_estimators': 1185, 'min_samples_split': 25, 'min_samples_leaf': 20, 'max_depth': 7}. Best is trial 0 with value: -21.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:27:33,651] Trial 20 finished with value: -36.666666666666664 and parameters: {'n_estimators': 1693, 'min_samples_split': 22, 'min_samples_leaf': 14, 'max_depth': 5}. Best is trial 0 with value: -21.666666666666668.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:27:42,193] Trial 21 finished with value: -25.0 and parameters: {'n_estimators': 1479, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_depth': 8}. Best is trial 0 with value: -21.666666666666668.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:27:49,770] Trial 22 finished with value: -20.0 and parameters: {'n_estimators': 1376, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_depth': 8}. Best is trial 22 with value: -20.0.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:28:00,868] Trial 23 finished with value: -28.333333333333332 and parameters: {'n_estimators': 1996, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_depth': 8}. Best is trial 22 with value: -20.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:28:06,836] Trial 24 finished with value: -31.666666666666668 and parameters: {'n_estimators': 1064, 'min_samples_split': 9, 'min_samples_leaf': 12, 'max_depth': 6}. Best is trial 22 with value: -20.0.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:28:14,369] Trial 25 finished with value: -28.333333333333332 and parameters: {'n_estimators': 1332, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_depth': 9}. Best is trial 22 with value: -20.0.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:28:24,014] Trial 26 finished with value: -41.666666666666664 and parameters: {'n_estimators': 1712, 'min_samples_split': 28, 'min_samples_leaf': 9, 'max_depth': 6}. Best is trial 22 with value: -20.0.
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:28:31,595] Trial 27 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1352, 'min_samples_split': 22, 'min_samples_leaf': 15, 'max_depth': 7}. Best is trial 22 with value: -20.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:28:37,733] Trial 28 finished with value: -36.666666666666664 and parameters: {'n_estimators': 1088, 'min_samples_split': 25, 'min_samples_leaf': 11, 'max_depth': 5}. Best is trial 22 with value: -20.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/2882548284.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:28:41,674] Trial 29 finished with value: -60.0 and parameters: {'n_estimators': 709, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_depth': 3}. Best is trial 22 with value: -20.0.

# %%
##Top 6 variables
class Objective:
    def __init__(self, seed):
        self.seed = seed
        
    def __call__(self, trial):
        params = dict(n_estimators = trial.suggest_int('n_estimators', 100, 2000),
                        min_samples_split = trial.suggest_int('min_samples_split', 6, 30),
                        min_samples_leaf = trial.suggest_int('min_samples_leaf', 6, 30),
                        max_depth = trial.suggest_int('max_depth', 2, 10)
                        )
        scores = list()
        
        skf = StratifiedKFold(n_splits = 3, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X_train_6, Y_train):
            X_train_1, X_valid_1 = X_train_6.iloc[train_idx], X_train_6.iloc[valid_idx]
            Y_train_1, Y_valid_1 = Y_train.iloc[train_idx], Y_train.iloc[valid_idx]
            
            RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
            pred_valid = RF_md.predict_proba(X_valid_1)[:, 1]
            score = cost_function(Y_valid_1, pred_valid)
            scores.append(score)
            
        return np.mean(scores)

# %%
SEED = 42
N_TRIALS = 30

study2 = optuna.create_study(direction = 'maximize')
study2.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-03-31 00:29:04,686] A new study created in memory with name: no-name-8a5c7d96-834f-4786-aea1-6799b1462de4
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:05,677] Trial 0 finished with value: -40.0 and parameters: {'n_estimators': 115, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_depth': 5}. Best is trial 0 with value: -40.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:11,493] Trial 1 finished with value: -36.666666666666664 and parameters: {'n_estimators': 1027, 'min_samples_split': 29, 'min_samples_leaf': 24, 'max_depth': 8}. Best is trial 1 with value: -36.666666666666664.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:19,887] Trial 2 finished with value: -41.666666666666664 and parameters: {'n_estimators': 1528, 'min_samples_split': 28, 'min_samples_leaf': 27, 'max_depth': 7}. Best is trial 1 with value: -36.666666666666664.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:27,742] Trial 3 finished with value: -40.0 and parameters: {'n_estimators': 1428, 'min_samples_split': 30, 'min_samples_leaf': 24, 'max_depth': 5}. Best is trial 1 with value: -36.666666666666664.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:28,678] Trial 4 finished with value: -38.333333333333336 and parameters: {'n_estimators': 143, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_depth': 5}. Best is trial 1 with value: -36.666666666666664.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:31,831] Trial 5 finished with value: -35.0 and parameters: {'n_estimators': 544, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_depth': 8}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:37,950] Trial 6 finished with value: -56.666666666666664 and parameters: {'n_estimators': 1176, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_depth': 3}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:47,999] Trial 7 finished with value: -40.0 and parameters: {'n_estimators': 1909, 'min_samples_split': 30, 'min_samples_leaf': 25, 'max_depth': 5}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:50,998] Trial 8 finished with value: -70.0 and parameters: {'n_estimators': 601, 'min_samples_split': 26, 'min_samples_leaf': 23, 'max_depth': 2}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:52,142] Trial 9 finished with value: -43.333333333333336 and parameters: {'n_estimators': 202, 'min_samples_split': 26, 'min_samples_leaf': 26, 'max_depth': 9}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:55,755] Trial 10 finished with value: -35.0 and parameters: {'n_estimators': 667, 'min_samples_split': 6, 'min_samples_leaf': 15, 'max_depth': 10}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:29:59,542] Trial 11 finished with value: -46.666666666666664 and parameters: {'n_estimators': 664, 'min_samples_split': 6, 'min_samples_leaf': 15, 'max_depth': 10}. Best is trial 5 with value: -35.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:02,676] Trial 12 finished with value: -45.0 and parameters: {'n_estimators': 567, 'min_samples_split': 21, 'min_samples_leaf': 14, 'max_depth': 10}. Best is trial 5 with value: -35.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:07,456] Trial 13 finished with value: -38.333333333333336 and parameters: {'n_estimators': 841, 'min_samples_split': 7, 'min_samples_leaf': 13, 'max_depth': 8}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:09,860] Trial 14 finished with value: -43.333333333333336 and parameters: {'n_estimators': 414, 'min_samples_split': 17, 'min_samples_leaf': 18, 'max_depth': 8}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:15,343] Trial 15 finished with value: -43.333333333333336 and parameters: {'n_estimators': 964, 'min_samples_split': 12, 'min_samples_leaf': 11, 'max_depth': 10}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:17,597] Trial 16 finished with value: -41.666666666666664 and parameters: {'n_estimators': 389, 'min_samples_split': 21, 'min_samples_leaf': 19, 'max_depth': 7}. Best is trial 5 with value: -35.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:21,916] Trial 17 finished with value: -18.333333333333332 and parameters: {'n_estimators': 745, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_depth': 9}. Best is trial 17 with value: -18.333333333333332.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:29,112] Trial 18 finished with value: -18.333333333333332 and parameters: {'n_estimators': 1261, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_depth': 7}. Best is trial 17 with value: -18.333333333333332.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:36,386] Trial 19 finished with value: -23.333333333333332 and parameters: {'n_estimators': 1276, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_depth': 6}. Best is trial 17 with value: -18.333333333333332.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:47,009] Trial 20 finished with value: -15.0 and parameters: {'n_estimators': 1779, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_depth': 7}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:30:57,901] Trial 21 finished with value: -18.333333333333332 and parameters: {'n_estimators': 1862, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_depth': 7}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:31:07,289] Trial 22 finished with value: -38.333333333333336 and parameters: {'n_estimators': 1664, 'min_samples_split': 14, 'min_samples_leaf': 30, 'max_depth': 6}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:31:17,617] Trial 23 finished with value: -41.666666666666664 and parameters: {'n_estimators': 1762, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_depth': 9}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:31:25,039] Trial 24 finished with value: -41.666666666666664 and parameters: {'n_estimators': 1275, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_depth': 9}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:31:36,673] Trial 25 finished with value: -25.0 and parameters: {'n_estimators': 1995, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_depth': 7}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:31:41,466] Trial 26 finished with value: -35.0 and parameters: {'n_estimators': 836, 'min_samples_split': 10, 'min_samples_leaf': 18, 'max_depth': 4}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:31:50,477] Trial 27 finished with value: -35.0 and parameters: {'n_estimators': 1554, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_depth': 6}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:31:57,655] Trial 28 finished with value: -28.333333333333332 and parameters: {'n_estimators': 1192, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_depth': 9}. Best is trial 20 with value: -15.0.
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/651894064.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:32:02,712] Trial 29 finished with value: -31.666666666666668 and parameters: {'n_estimators': 873, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_depth': 4}. Best is trial 20 with value: -15.0.

# %%
##Top 7 variables
class Objective:
    def __init__(self, seed):
        self.seed = seed
        
    def __call__(self, trial):
        params = dict(n_estimators = trial.suggest_int('n_estimators', 100, 2000),
                        min_samples_split = trial.suggest_int('min_samples_split', 7, 30),
                        min_samples_leaf = trial.suggest_int('min_samples_leaf', 7, 30),
                        max_depth = trial.suggest_int('max_depth', 2, 10)
                        )
        scores = list()
        
        skf = StratifiedKFold(n_splits = 3, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X_train_7, Y_train):
            X_train_1, X_valid_1 = X_train_7.iloc[train_idx], X_train_7.iloc[valid_idx]
            Y_train_1, Y_valid_1 = Y_train.iloc[train_idx], Y_train.iloc[valid_idx]
            
            RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
            pred_valid = RF_md.predict_proba(X_valid_1)[:, 1]
            score = cost_function(Y_valid_1, pred_valid)
            scores.append(score)
            
        return np.mean(scores)

# %%
SEED = 42
N_TRIALS = 30

study3 = optuna.create_study(direction = 'maximize')
study3.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-03-31 00:43:56,644] A new study created in memory with name: no-name-74d4ad7b-aa99-4b65-bdf1-37830722f104
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:01,384] Trial 0 finished with value: -51.666666666666664 and parameters: {'n_estimators': 748, 'min_samples_split': 14, 'min_samples_leaf': 30, 'max_depth': 9}. Best is trial 0 with value: -51.666666666666664.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:04,464] Trial 1 finished with value: -43.333333333333336 and parameters: {'n_estimators': 563, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_depth': 3}. Best is trial 1 with value: -43.333333333333336.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:15,121] Trial 2 finished with value: -48.333333333333336 and parameters: {'n_estimators': 1957, 'min_samples_split': 18, 'min_samples_leaf': 15, 'max_depth': 4}. Best is trial 1 with value: -43.333333333333336.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:16,020] Trial 3 finished with value: -51.666666666666664 and parameters: {'n_estimators': 146, 'min_samples_split': 23, 'min_samples_leaf': 17, 'max_depth': 4}. Best is trial 1 with value: -43.333333333333336.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:25,955] Trial 4 finished with value: -41.666666666666664 and parameters: {'n_estimators': 1822, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_depth': 4}. Best is trial 4 with value: -41.666666666666664.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:31,344] Trial 5 finished with value: -50.0 and parameters: {'n_estimators': 964, 'min_samples_split': 26, 'min_samples_leaf': 30, 'max_depth': 8}. Best is trial 4 with value: -41.666666666666664.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:32,640] Trial 6 finished with value: -43.333333333333336 and parameters: {'n_estimators': 220, 'min_samples_split': 17, 'min_samples_leaf': 14, 'max_depth': 4}. Best is trial 4 with value: -41.666666666666664.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:40,234] Trial 7 finished with value: -46.666666666666664 and parameters: {'n_estimators': 1429, 'min_samples_split': 25, 'min_samples_leaf': 21, 'max_depth': 3}. Best is trial 4 with value: -41.666666666666664.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:44,292] Trial 8 finished with value: -31.666666666666668 and parameters: {'n_estimators': 667, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_depth': 6}. Best is trial 8 with value: -31.666666666666668.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:46,098] Trial 9 finished with value: -55.0 and parameters: {'n_estimators': 327, 'min_samples_split': 22, 'min_samples_leaf': 24, 'max_depth': 5}. Best is trial 8 with value: -31.666666666666668.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:44:53,038] Trial 10 finished with value: -25.0 and parameters: {'n_estimators': 1221, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_depth': 7}. Best is trial 10 with value: -25.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:45:00,194] Trial 11 finished with value: -20.0 and parameters: {'n_estimators': 1323, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_depth': 7}. Best is trial 11 with value: -20.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:45:07,370] Trial 12 finished with value: -33.333333333333336 and parameters: {'n_estimators': 1321, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_depth': 7}. Best is trial 11 with value: -20.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:45:15,324] Trial 13 finished with value: -31.666666666666668 and parameters: {'n_estimators': 1388, 'min_samples_split': 30, 'min_samples_leaf': 7, 'max_depth': 10}. Best is trial 11 with value: -20.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:45:21,683] Trial 14 finished with value: -25.0 and parameters: {'n_estimators': 1125, 'min_samples_split': 7, 'min_samples_leaf': 11, 'max_depth': 7}. Best is trial 11 with value: -20.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:45:30,766] Trial 15 finished with value: -33.333333333333336 and parameters: {'n_estimators': 1640, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_depth': 8}. Best is trial 11 with value: -20.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:45:36,578] Trial 16 finished with value: -43.333333333333336 and parameters: {'n_estimators': 1029, 'min_samples_split': 13, 'min_samples_leaf': 11, 'max_depth': 6}. Best is trial 11 with value: -20.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:45:45,522] Trial 17 finished with value: -55.0 and parameters: {'n_estimators': 1624, 'min_samples_split': 10, 'min_samples_leaf': 24, 'max_depth': 7}. Best is trial 11 with value: -20.0.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:45:52,619] Trial 18 finished with value: -13.333333333333334 and parameters: {'n_estimators': 1227, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_depth': 10}. Best is trial 18 with value: -13.333333333333334.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:01,257] Trial 19 finished with value: -40.0 and parameters: {'n_estimators': 1539, 'min_samples_split': 16, 'min_samples_leaf': 12, 'max_depth': 10}. Best is trial 18 with value: -13.333333333333334.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:06,210] Trial 20 finished with value: -48.333333333333336 and parameters: {'n_estimators': 879, 'min_samples_split': 20, 'min_samples_leaf': 16, 'max_depth': 9}. Best is trial 18 with value: -13.333333333333334.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:13,154] Trial 21 finished with value: -23.333333333333332 and parameters: {'n_estimators': 1218, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_depth': 8}. Best is trial 18 with value: -13.333333333333334.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:20,051] Trial 22 finished with value: -31.666666666666668 and parameters: {'n_estimators': 1218, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_depth': 9}. Best is trial 18 with value: -13.333333333333334.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:26,323] Trial 23 finished with value: -11.666666666666666 and parameters: {'n_estimators': 1101, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_depth': 8}. Best is trial 23 with value: -11.666666666666666.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:31,255] Trial 24 finished with value: -31.666666666666668 and parameters: {'n_estimators': 842, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_depth': 10}. Best is trial 23 with value: -11.666666666666666.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:37,356] Trial 25 finished with value: -48.333333333333336 and parameters: {'n_estimators': 1081, 'min_samples_split': 10, 'min_samples_leaf': 13, 'max_depth': 9}. Best is trial 23 with value: -11.666666666666666.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:45,710] Trial 26 finished with value: -35.0 and parameters: {'n_estimators': 1475, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_depth': 8}. Best is trial 23 with value: -11.666666666666666.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:56,041] Trial 27 finished with value: -31.666666666666668 and parameters: {'n_estimators': 1740, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_depth': 6}. Best is trial 23 with value: -11.666666666666666.
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:46:59,053] Trial 28 finished with value: -40.0 and parameters: {'n_estimators': 523, 'min_samples_split': 12, 'min_samples_leaf': 18, 'max_depth': 10}. Best is trial 23 with value: -11.666666666666666.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# /tmp/ipykernel_12620/3304813430.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_md = RandomForestClassifier(**params).fit(X_train_1, Y_train_1)
# [I 2023-03-31 00:47:03,172] Trial 29 finished with value: -50.0 and parameters: {'n_estimators': 734, 'min_samples_split': 14, 'min_samples_leaf': 29, 'max_depth': 9}. Best is trial 23 with value: -11.666666666666666.

# %%
print('The best parameters for the top 5 variables is:', study.best_trial.params)
print('The best parameters for the top 6 variables is:', study2.best_trial.params)
print('The best parameters for the top 7 variables is:', study3.best_trial.params)

'''
Trial 29 finished with value: -60.0 and parameters: {'n_estimators': 709, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_depth': 3}. Best is trial 22 with value: -20.0.
Trial 29 finished with value: -31.666666666666668 and parameters: {'n_estimators': 873, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_depth': 4}. Best is trial 20 with value: -15.0.
Trial 29 finished with value: -50.0 and parameters: {'n_estimators': 734, 'min_samples_split': 14, 'min_samples_leaf': 29, 'max_depth': 9}. Best is trial 23 with value: -11.666666666666666.
'''
# Out:
# The best parameters for the top 5 variables is: {'n_estimators': 1376, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_depth': 8}
# The best parameters for the top 6 variables is: {'n_estimators': 1779, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_depth': 7}
# The best parameters for the top 7 variables is: {'n_estimators': 1101, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_depth': 8}

# %% [markdown]
# ## Exercise 3
#
# (70 points) Using the train data-frame and the models from exercise 2, split the train data-frame
# into two data-frames: training (80%) and validation (20%) taking into account the proportions
# of 0s and 1s. Then, do the following:

# %%
X = train[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds',
                   'tree_interaction_2', 'interaction_1', 'lineItemVoidsPerPosition_squared', 'lineItemsVoids']]
Y = train['fraud']

X_training, X_valid, Y_training, Y_valid = train_test_split(X, Y, test_size = .2, stratify = Y)

# %%
test1 = test[['log10_totalScanTimeInSeconds', 'interaction_3', 'totalScanTimeInSeconds',
                   'tree_interaction_2', 'interaction_1', 'lineItemVoidsPerPosition_squared', 'lineItemsVoids']]

# %% [markdown]
# (i) Consider the best model from exercise 2(i). Build that model on the training data-frame.
# After that, predict the likelihood of fraud on the validation and test data-frames.

# %%
'''
The best params with Gradient Boosting and GridSearchCV for the top 7 variables is: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 15, 'n_estimators': 100}
The best score for the top 7 variables is: 11.666666666666666
'''

##building the model
GB_md = GradientBoostingClassifier(n_estimators = 100, max_depth = 3, learning_rate = 0.1,
                                   min_samples_leaf = 7, min_samples_split = 15).fit(X_training, Y_training)
##predicting on validation and test
GB_val_pred = GB_md.predict_proba(X_valid)[:, 1]
GB_test_pred = GB_md.predict_proba(test1)[:, 1]

##computing cost
print('Cost function score of GB model:',cost_function(Y_valid, GB_val_pred))
print('Cutoff value for GB model:', cost_function_cutoff(Y_valid, GB_val_pred))
# Out:
# Cost function score of GB model: 35.0
# Cutoff value for GB model: 0.6

# %% [markdown]
# (ii) Consider the best model from exercise 2(ii). Build that model on the training data-frame.
# After that, predict the likelihood of fraud on the validation and test data-frames

# %%
'''
The best params with ADAboost and RandomizedSearchCV for the top 7 variables is: {'n_estimators': 100, 'learning_rate': 0.1, 'estimator__min_samples_split': 10, 'estimator__min_samples_leaf': 5, 'estimator__max_depth': 3}
The best score is: 3.3333333333333335
'''
##building the model
ADA_md = AdaBoostClassifier(estimator = DecisionTreeClassifier(max_depth = 3, min_samples_leaf = 5, min_samples_split = 10),
                        learning_rate = 0.1, n_estimators = 100).fit(X_training, Y_training)
##predicting on validation and test
ADA_val_pred = ADA_md.predict_proba(X_valid)[:, 1]
ADA_test_pred = ADA_md.predict_proba(test1)[:, 1]

##computing cost
print('Cost function score of ADA model:',cost_function(Y_valid, ADA_val_pred))
print('Cutoff value for ADA model:', cost_function_cutoff(Y_valid, ADA_val_pred))
# Out:
# Cost function score of ADA model: 20.0
# Cutoff value for ADA model: 0.63

# %% [markdown]
# (iii) Consider the best model from exercise 2(iii). Build that model on the training data-frame.
# After that, predict the likelihood of fraud on the validation and test data-frames.

# %%
'''
Best is trial 23 with value: -11.666666666666666
The best parameters for the top 7 variables is: {'n_estimators': 1101, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_depth': 8}
'''

##building the model
RF_md = RandomForestClassifier(max_depth = 8, min_samples_leaf = 7, min_samples_split = 9, n_estimators = 1101).fit(X_training, Y_training)

##predicting on validation and test
RF_val_pred = RF_md.predict_proba(X_valid)[:, 1]
RF_test_pred = RF_md.predict_proba(test1)[:, 1]

##computing cost
print('Cost function score of RF model:',cost_function(Y_valid, RF_val_pred))
print('Cutoff value for RF model:',cost_function_cutoff(Y_valid, RF_val_pred))
# Out:
# Cost function score of RF model: -10.0
# Cutoff value for RF model: 0.44

# %% [markdown]
# Using the prediction on the validation data-frame as inputs from parts (i)-(ii)-(iii) and the
# actual fraud values from the validation data-frame as the target variable, build a meta-learner
# to predict fraud. Make sure to tune the hyper-parameters of the meta-learner keeping in mind how
# the results are going to be evaluated. For more info, see page 4 of DATA-MINING-CUP-2019-task.pdf
# file. Finally, use the best meta-learner to predict the likelihood of fraud in the test data-frame.
# Submit the likelihoods in a csv file. Also submit the associated cut-off value

# %%
X_ensemble = pd.concat([pd.DataFrame(GB_val_pred),pd.DataFrame(ADA_val_pred), pd.DataFrame(RF_val_pred)], axis = 1)
X_testensemble = pd.concat([pd.DataFrame(GB_test_pred),pd.DataFrame(ADA_test_pred), pd.DataFrame(RF_test_pred)], axis = 1)

X = X_ensemble
Y = Y_valid

class Objective:
    def __init__(self, seed):
        self.seed = seed

    def __call__(self, trial):
        ## Parameters to be evaluated
        params = dict(n_estimators = trial.suggest_int('n_estimators', 100, 2000),
        min_samples_split = trial.suggest_int('min_samples_split', 5, 30),
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 5, 30),
        max_depth = trial.suggest_int('max_depth', 2, 10)
        )
        scores = []
        ## Running cross validation
        skf = StratifiedKFold(n_splits = 3, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X, Y):
            
            X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
            Y_train , Y_valid = Y.iloc[train_idx] , Y.iloc[valid_idx]
            RF_md = RandomForestClassifier(**params).fit(X_train, Y_train)
            preds_valid = RF_md.predict_proba(X_valid)[:, 1]
            score = cost_function(Y_valid, preds_valid)
            scores.append(score)
        return np.mean(scores)

# %%
#defining seed and number of trials
SEED = 42
N_TRIALS = 30

#execute an optimization
study = optuna.create_study(direction = 'maximize')
study.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-03-31 02:41:06,071] A new study created in memory with name: no-name-66df7cad-4405-4a24-abb0-5ede53859546
# [I 2023-03-31 02:41:13,629] Trial 0 finished with value: 11.666666666666666 and parameters: {'n_estimators': 1689, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_depth': 10}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:16,777] Trial 1 finished with value: -35.0 and parameters: {'n_estimators': 736, 'min_samples_split': 18, 'min_samples_leaf': 28, 'max_depth': 7}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:24,302] Trial 2 finished with value: -3.3333333333333335 and parameters: {'n_estimators': 1788, 'min_samples_split': 26, 'min_samples_leaf': 14, 'max_depth': 9}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:24,825] Trial 3 finished with value: 11.666666666666666 and parameters: {'n_estimators': 101, 'min_samples_split': 29, 'min_samples_leaf': 5, 'max_depth': 3}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:29,198] Trial 4 finished with value: 11.666666666666666 and parameters: {'n_estimators': 1024, 'min_samples_split': 19, 'min_samples_leaf': 7, 'max_depth': 9}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:35,689] Trial 5 finished with value: -28.333333333333332 and parameters: {'n_estimators': 1504, 'min_samples_split': 19, 'min_samples_leaf': 21, 'max_depth': 4}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:37,022] Trial 6 finished with value: -28.333333333333332 and parameters: {'n_estimators': 297, 'min_samples_split': 30, 'min_samples_leaf': 19, 'max_depth': 10}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:44,603] Trial 7 finished with value: 8.333333333333334 and parameters: {'n_estimators': 1795, 'min_samples_split': 30, 'min_samples_leaf': 10, 'max_depth': 6}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:51,616] Trial 8 finished with value: -35.0 and parameters: {'n_estimators': 1666, 'min_samples_split': 29, 'min_samples_leaf': 28, 'max_depth': 5}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:41:57,922] Trial 9 finished with value: -35.0 and parameters: {'n_estimators': 1465, 'min_samples_split': 18, 'min_samples_leaf': 25, 'max_depth': 7}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:42:02,556] Trial 10 finished with value: 0.0 and parameters: {'n_estimators': 1100, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# [I 2023-03-31 02:42:03,808] Trial 11 finished with value: 11.666666666666666 and parameters: {'n_estimators': 271, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_depth': 2}. Best is trial 0 with value: 11.666666666666666.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# [I 2023-03-31 02:42:06,489] Trial 12 finished with value: 15.0 and parameters: {'n_estimators': 603, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_depth': 4}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:10,525] Trial 13 finished with value: -11.666666666666666 and parameters: {'n_estimators': 941, 'min_samples_split': 12, 'min_samples_leaf': 15, 'max_depth': 5}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:12,680] Trial 14 finished with value: 10.0 and parameters: {'n_estimators': 487, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_depth': 8}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:18,449] Trial 15 finished with value: 8.333333333333334 and parameters: {'n_estimators': 1323, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_depth': 4}. Best is trial 12 with value: 15.0.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/optuna/samplers/_tpe/_erf.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   s = one / (x * x)
# [I 2023-03-31 02:42:21,324] Trial 16 finished with value: -11.666666666666666 and parameters: {'n_estimators': 663, 'min_samples_split': 15, 'min_samples_leaf': 15, 'max_depth': 10}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:26,481] Trial 17 finished with value: 11.666666666666666 and parameters: {'n_estimators': 1204, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_depth': 6}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:29,871] Trial 18 finished with value: 11.666666666666666 and parameters: {'n_estimators': 782, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_depth': 4}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:38,028] Trial 19 finished with value: -1.6666666666666667 and parameters: {'n_estimators': 1936, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_depth': 8}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:40,242] Trial 20 finished with value: -35.0 and parameters: {'n_estimators': 506, 'min_samples_split': 24, 'min_samples_leaf': 22, 'max_depth': 3}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:40,935] Trial 21 finished with value: 11.666666666666666 and parameters: {'n_estimators': 137, 'min_samples_split': 22, 'min_samples_leaf': 5, 'max_depth': 3}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:43,225] Trial 22 finished with value: 11.666666666666666 and parameters: {'n_estimators': 513, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_depth': 3}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:43,788] Trial 23 finished with value: 11.666666666666666 and parameters: {'n_estimators': 106, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_depth': 5}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:47,660] Trial 24 finished with value: -1.6666666666666667 and parameters: {'n_estimators': 900, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_depth': 2}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:49,225] Trial 25 finished with value: 11.666666666666666 and parameters: {'n_estimators': 346, 'min_samples_split': 21, 'min_samples_leaf': 9, 'max_depth': 4}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:54,648] Trial 26 finished with value: 11.666666666666666 and parameters: {'n_estimators': 1272, 'min_samples_split': 27, 'min_samples_leaf': 8, 'max_depth': 3}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:57,398] Trial 27 finished with value: -20.0 and parameters: {'n_estimators': 635, 'min_samples_split': 14, 'min_samples_leaf': 17, 'max_depth': 5}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:42:59,173] Trial 28 finished with value: -1.6666666666666667 and parameters: {'n_estimators': 397, 'min_samples_split': 10, 'min_samples_leaf': 11, 'max_depth': 7}. Best is trial 12 with value: 15.0.
# [I 2023-03-31 02:43:02,621] Trial 29 finished with value: -35.0 and parameters: {'n_estimators': 802, 'min_samples_split': 17, 'min_samples_leaf': 30, 'max_depth': 8}. Best is trial 12 with value: 15.0.
