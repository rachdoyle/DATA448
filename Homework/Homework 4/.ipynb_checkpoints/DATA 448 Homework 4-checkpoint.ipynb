# %%
import boto3
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

##defining the bucket
s3 = boto3.resource('s3')
bucket_name = 'rachaeld-data445'
bucket = s3.Bucket(bucket_name)

#defining the csv file
file_key = 'train.csv'
file_key2 = 'test.csv'

##train
bucket_object = bucket.Object(file_key)
file_object = bucket_object.get()
file_content_stream = file_object.get('Body')

##test
bucket_object2 = bucket.Object(file_key2)
file_object2 = bucket_object2.get()
file_content_stream2 = file_object2.get('Body')

train = pd.read_csv(file_content_stream)
test = pd.read_csv(file_content_stream2)

# %%
train.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemsVoids  \
# 0           5                    1054       54.70               7
# 1           3                     108       27.36               5
# 2           3                    1516       62.16               3
# 3           6                    1791       92.31               8
# 4           5                     430       81.53               3
#
#    scansWithoutRegistration  quanitityModification  scannedLineItemsPerSecond  \
# 0                         0                      3                   0.027514
# 1                         2                      4                   0.129630
# 2                        10                      5                   0.008575
# 3                         4                      4                   0.016192
# 4                         7                      2                   0.062791
#
#    valuePerSecond  lineItemVoidsPerPosition  fraud
# 0        0.051898                  0.241379      0
# 1        0.253333                  0.357143      0
# 2        0.041003                  0.230769      0
# 3        0.051541                  0.275862      0
# 4        0.189605                  0.111111      0

# %%
test.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0         4.0                   467.0       88.48              4
# 1         3.0                  1004.0       58.99              7
# 2         1.0                   162.0       14.00              4
# 3         5.0                   532.0       84.79              9
# 4         5.0                   890.0       42.16              4
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         8                      4                   0.014989
# 1                         6                      1                   0.026892
# 2                         5                      4                   0.006173
# 3                         3                      4                   0.026316
# 4                         0                      0                   0.021348
#
#    valuePerSecond  lineItemVoidsPerPosition
# 0        0.189465                  0.571429
# 1        0.058755                  0.259259
# 2        0.086420                  4.000000
# 3        0.159380                  0.642857
# 4        0.047371                  0.210526

# %% [markdown]
# ##(55 points) Using the train data-frame, engineer at least 7 different features, that can help to
# predict fraud, using the given input variables. Engineer the same features, that you engineer on
# the train data-frame, on the test data-frame. These are the rules to engineer the features:
# • You can use the Box-Cox transformation only one time.

# %%
##trust level
plt.hist(x=train['scansWithoutRegistration'], bins=10)
plt.show()

# %%
## engineering variables
##boxcox
transformed_trustLevel= boxcox(train['trustLevel'])
train['newtrustLevel'] = transformed_trustLevel[0]
transformed_trustLevel= boxcox(test['trustLevel'])
test['newtrustLevel'] = transformed_trustLevel[0]

##1/x
train['1/scannedLineItemsPerSecond']= 1/(train['scannedLineItemsPerSecond'])
test['1/scannedLineItemsPerSecond']= 1/(test['scannedLineItemsPerSecond'])

##^2
train['lineItemVoidsPerPosition_squared'] = train['lineItemVoidsPerPosition']**2
test['lineItemVoidsPerPosition_squared'] = test['lineItemVoidsPerPosition']**2

##^3
train['valuePerSecond_cubed'] = train['valuePerSecond'] **3
test['valuePerSecond_cubed'] = test['valuePerSecond'] **3

##natural log
train['Naturallog_grandTotal'] = np.log(train['grandTotal'])
test['Naturallog_grandTotal'] = np.log(test['grandTotal'])

##log base 10
train['log10_totalScanTimeInSeconds'] = np.log10(train['totalScanTimeInSeconds'])
test['log10_totalScanTimeInSeconds'] = np.log10(test['totalScanTimeInSeconds'])

## >5
train['0_1_scansWithoutRegistration'] = np.where(train['scansWithoutRegistration'] < 5, 0, 1) 
test['0_1_scansWithoutRegistration'] = np.where(test['scansWithoutRegistration'] < 5, 0, 1)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
train
# Out:
#       trustLevel  totalScanTimeInSeconds  grandTotal  lineItemsVoids  \
# 0              5                    1054       54.70               7
# 1              3                     108       27.36               5
# 2              3                    1516       62.16               3
# 3              6                    1791       92.31               8
# 4              5                     430       81.53               3
# ...          ...                     ...         ...             ...
# 1874           1                     321       76.03               8
# 1875           1                     397       41.89               5
# 1876           4                     316       41.83               5
# 1877           2                     685       62.68               1
# 1878           4                    1140       38.03               2
#
#       scansWithoutRegistration  quanitityModification  \
# 0                            0                      3
# 1                            2                      4
# 2                           10                      5
# 3                            4                      4
# 4                            7                      2
# ...                        ...                    ...
# 1874                         7                      2
# 1875                         5                      0
# 1876                         8                      1
# 1877                         6                      2
# 1878                         2                      3
#
#       scannedLineItemsPerSecond  valuePerSecond  lineItemVoidsPerPosition  \
# 0                      0.027514        0.051898                  0.241379
# 1                      0.129630        0.253333                  0.357143
# 2                      0.008575        0.041003                  0.230769
# 3                      0.016192        0.051541                  0.275862
# 4                      0.062791        0.189605                  0.111111
# ...                         ...             ...                       ...
# 1874                   0.071651        0.236854                  0.347826
# 1875                   0.065491        0.105516                  0.192308
# 1876                   0.094937        0.132373                  0.166667
# 1877                   0.035036        0.091504                  0.041667
# 1878                   0.016667        0.033360                  0.105263
#
#       fraud  newtrustLevel  1/scannedLineItemsPerSecond  \
# 0         0       2.728286                    36.344828
# 1         0       1.561821                     7.714286
# 2         0       1.561821                   116.615383
# 3         0       3.240277                    61.758622
# 4         0       2.728286                    15.925926
# ...     ...            ...                          ...
# 1874      0       0.000000                    13.956522
# 1875      1       0.000000                    15.269231
# 1876      0       2.174059                    10.533333
# 1877      0       0.861716                    28.541667
# 1878      0       2.174059                    59.999999
#
#       lineItemVoidsPerPosition_squared  valuePerSecond_cubed  \
# 0                             0.058264              0.000140
# 1                             0.127551              0.016258
# 2                             0.053254              0.000069
# 3                             0.076100              0.000137
# 4                             0.012346              0.006816
# ...                                ...                   ...
# 1874                          0.120983              0.013287
# 1875                          0.036982              0.001175
# 1876                          0.027778              0.002320
# 1877                          0.001736              0.000766
# 1878                          0.011080              0.000037
#
#       Naturallog_grandTotal  log10_totalScanTimeInSeconds  \
# 0                  4.001864                      3.022841
# 1                  3.309082                      2.033424
# 2                  4.129712                      3.180699
# 3                  4.525152                      3.253096
# 4                  4.400971                      2.633468
# ...                     ...                           ...
# 1874               4.331128                      2.506505
# 1875               3.735047                      2.598791
# 1876               3.733614                      2.499687
# 1877               4.138042                      2.835691
# 1878               3.638375                      3.056905
#
#       0_1_scansWithoutRegistration
# 0                                0
# 1                                0
# 2                                1
# 3                                0
# 4                                1
# ...                            ...
# 1874                             1
# 1875                             1
# 1876                             1
# 1877                             1
# 1878                             0
#
# [1879 rows x 17 columns]

# %% [markdown]
# (a) Engineer three feature by using the strong heredity principle. That is, identify the top three
# features and engineer the interaction between them. For examples, let’s assume X3, X12 and
# X8 are the top three features, then the interactions would be X3×X12, X3×X8, and X12×X8.
# Notice that you can use a tree-based model (since you can extract feature importance) to
# identify important features. You can follow these steps:
#
# (i) Split the train data-frame (including the features that were engineered in homework
# assignment 4) intro training (80%) and testing (20%) (taking into account the proportions of 0s and 1s).
#
# (ii) Build a random forest model with 500 trees and depth equal to 3 on the training
# data-frame. Extract and store the importance of each of the features.
# Repeat (i)-(ii) 100 times. Then, compute the average importance for each of the features.

# %%
##defining the list to store feature importances
importance = list()

for i in range (0,10):
    ##defining input and target variables
    X = train.drop(columns = 'fraud', axis = 1)
    Y = train['fraud']
    
    ##splitting the train data 
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .2, stratify = Y)
    
    ##buinding the RF model
    RF = RandomForestClassifier(n_estimators = 500, max_depth = 3).fit(X_train, Y_train)
    
    ##extracting the feature importances
    importance.append(RF.feature_importances_)
    
##transforming list into data-frame
importance = pd.DataFrame(importance)
importance.columns = X.columns

## average of the importances 
importance = pd.DataFrame(importance.apply(np.mean, axis = 0))
importance
# Out:
#                                          0
# trustLevel                        0.237694
# totalScanTimeInSeconds            0.063099
# grandTotal                        0.016929
# lineItemsVoids                    0.026153
# scansWithoutRegistration          0.011439
# quanitityModification             0.000876
# scannedLineItemsPerSecond         0.072332
# valuePerSecond                    0.033647
# lineItemVoidsPerPosition          0.054525
# newtrustLevel                     0.236602
# 1/scannedLineItemsPerSecond       0.078493
# lineItemVoidsPerPosition_squared  0.052959
# valuePerSecond_cubed              0.029628
# Naturallog_grandTotal             0.016157
# log10_totalScanTimeInSeconds      0.062346
# 0_1_scansWithoutRegistration      0.007121

# %%
##engineering interactions based on feature importance
train['interaction_1'] = train['trustLevel'] * train['totalScanTimeInSeconds']
test['interaction_1'] = test['trustLevel'] * test['totalScanTimeInSeconds']

train['interaction_2'] = train['trustLevel'] * train['grandTotal']
test['interaction_2'] = test['trustLevel'] * train['grandTotal']

train['interaction_3'] = train['totalScanTimeInSeconds'] * train['grandTotal']
test['interaction_3'] = test['totalScanTimeInSeconds'] * test['grandTotal']

# %%
## defining the input and target variables
X = train.drop(columns = ['fraud'], axis = 1)
Y = train['fraud']

##splitting the data 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .2, stratify = Y)

##building decision tree
tree_md = DecisionTreeClassifier(max_depth = 4).fit(X_train, Y_train)

fig = plt.figure(figsize = (25,20))
plot_tree(tree_md, feature_names = X_train.columns, filled = True)
# Out:
# [Text(0.5921052631578947, 0.9, 'newtrustLevel <= 0.431\ngini = 0.104\nsamples = 1503\nvalue = [1420, 83]'),
#  Text(0.2894736842105263, 0.7, 'scannedLineItemsPerSecond <= 0.012\ngini = 0.403\nsamples = 254\nvalue = [183, 71]'),
#  Text(0.10526315789473684, 0.5, 'lineItemsVoids <= 10.5\ngini = 0.024\nsamples = 83\nvalue = [82, 1]'),
#  Text(0.05263157894736842, 0.3, 'gini = 0.0\nsamples = 80\nvalue = [80, 0]'),
#  Text(0.15789473684210525, 0.3, 'lineItemVoidsPerPosition <= 0.748\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.10526315789473684, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21052631578947367, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.47368421052631576, 0.5, 'log10_totalScanTimeInSeconds <= 2.952\ngini = 0.484\nsamples = 171\nvalue = [101, 70]'),
#  Text(0.3684210526315789, 0.3, 'scansWithoutRegistration <= 6.5\ngini = 0.315\nsamples = 107\nvalue = [86, 21]'),
#  Text(0.3157894736842105, 0.1, 'gini = 0.163\nsamples = 67\nvalue = [61, 6]'),
#  Text(0.42105263157894735, 0.1, 'gini = 0.469\nsamples = 40\nvalue = [25, 15]'),
#  Text(0.5789473684210527, 0.3, '1/scannedLineItemsPerSecond <= 67.634\ngini = 0.359\nsamples = 64\nvalue = [15, 49]'),
#  Text(0.5263157894736842, 0.1, 'gini = 0.223\nsamples = 47\nvalue = [6, 41]'),
#  Text(0.631578947368421, 0.1, 'gini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.8947368421052632, 0.7, 'interaction_3 <= 169869.109\ngini = 0.019\nsamples = 1249\nvalue = [1237, 12]'),
#  Text(0.8421052631578947, 0.5, 'trustLevel <= 2.5\ngini = 0.017\nsamples = 1248\nvalue = [1237, 11]'),
#  Text(0.7894736842105263, 0.3, 'totalScanTimeInSeconds <= 1298.0\ngini = 0.076\nsamples = 278\nvalue = [267, 11]'),
#  Text(0.7368421052631579, 0.1, 'gini = 0.01\nsamples = 193\nvalue = [192, 1]'),
#  Text(0.8421052631578947, 0.1, 'gini = 0.208\nsamples = 85\nvalue = [75, 10]'),
#  Text(0.8947368421052632, 0.3, 'gini = 0.0\nsamples = 970\nvalue = [970, 0]'),
#  Text(0.9473684210526315, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]
